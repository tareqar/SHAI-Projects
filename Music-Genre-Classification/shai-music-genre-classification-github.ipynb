# %% [markdown]
# # Music Genre Classification Prediction

# %% [markdown]
# Dataset Information:
#
# artist: Name of the Artist.
#
# song: Name of the Track.
#
# popularity: The higher the value the more popular the song is.
#
# danceability: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm
#
# energy: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity.
#
# key: The key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on..
#
# loudness: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative
#
# mode: Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
#
# speechiness: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# acousticness: A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# instrumentalness: Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# liveness: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# valence: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# tempo: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# duration in milliseconds :Time of the song
#
# time_signature : a notational convention used in Western musical notation to specify how many beats (pulses) are contained in each measure (bar), and which note value is equivalent to a beat.
#
# Class: Genre of the track.

# %% [markdown]
# ## Importing libraries and training data:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score,cross_val_predict, RandomizedSearchCV
from pandas.plotting import scatter_matrix
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn import preprocessing

# %%
train_set = pd.read_csv('file-location')
train_set.drop(['Id'], axis=1, inplace=True) 
print("train_set shape is: ", train_set.shape)
train_set.head()
# Out:
# train_set shape is:  (14396, 17)
#            Artist Name       Track Name  Popularity  danceability  energy  \
# 0    Marina Maximilian       Not Afraid        37.0         0.334   0.536
# 1       The Black Keys  Howlin' for You        67.0         0.725   0.747
# 2  Royal & the Serpent          phuck u         NaN         0.584   0.804
# 3   Detroit Blues Band      Missing You        12.0         0.515   0.308
# 4         Coast Contra          My Lady        48.0         0.565   0.777
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   9.0    -6.649     0       0.0381      0.378000               NaN
# 1  11.0    -5.545     1       0.0876      0.027200            0.0468
# 2   7.0    -6.094     1       0.0619      0.000968            0.6350
# 3   NaN   -14.711     1       0.0312      0.907000            0.0213
# 4   6.0    -5.096     0       0.2490      0.183000               NaN
#
#    liveness  valence    tempo  duration_in min/ms  time_signature  Class
# 0     0.106    0.235  152.429            204947.0               4      9
# 1     0.104    0.380  132.921            191956.0               4      6
# 2     0.284    0.635  159.953            161037.0               4     10
# 3     0.300    0.501  172.472            298093.0               3      2
# 4     0.211    0.619   88.311            254145.0               4      5

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14396 entries, 0 to 14395
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Artist Name         14396 non-null  object
#  1   Track Name          14396 non-null  object
#  2   Popularity          14063 non-null  float64
#  3   danceability        14396 non-null  float64
#  4   energy              14396 non-null  float64
#  5   key                 12787 non-null  float64
#  6   loudness            14396 non-null  float64
#  7   mode                14396 non-null  int64
#  8   speechiness         14396 non-null  float64
#  9   acousticness        14396 non-null  float64
#  10  instrumentalness    10855 non-null  float64
#  11  liveness            14396 non-null  float64
#  12  valence             14396 non-null  float64
#  13  tempo               14396 non-null  float64
#  14  duration_in min/ms  14396 non-null  float64
#  15  time_signature      14396 non-null  int64
#  16  Class               14396 non-null  int64
# dtypes: float64(12), int64(3), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# Modifying Columns' names

# %%
#Removes spaces and changes upper case letters to lower case letters
print("Column names: ", train_set.columns)
train_set.columns= train_set.columns.str.replace(" ","_").str.lower()
print("Column names after: ", train_set.columns)
# Out:
# Column names:  Index(['Artist Name', 'Track Name', 'Popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_in min/ms', 'time_signature', 'Class'],
#       dtype='object')
# Column names after:  Index(['artist_name', 'track_name', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_in_min/ms', 'time_signature', 'class'],
#       dtype='object')

# %% [markdown]
# Taking a look at the values:

# %%
train_set.describe()
# Out:
#          popularity  danceability        energy           key      loudness  \
# count  14063.000000  14396.000000  14396.000000  12787.000000  14396.000000
# mean      44.525208      0.543105      0.662422      5.953781     -7.900852
# std       17.418940      0.165517      0.235967      3.200013      4.057362
# min        1.000000      0.059600      0.001210      1.000000    -39.952000
# 25%       33.000000      0.432000      0.508000      3.000000     -9.538000
# 50%       44.000000      0.545000      0.699000      6.000000     -7.013500
# 75%       56.000000      0.658000      0.861000      9.000000     -5.162000
# max      100.000000      0.989000      1.000000     11.000000      1.342000
#
#                mode   speechiness  acousticness  instrumentalness  \
# count  14396.000000  14396.000000  14396.000000      10855.000000
# mean       0.640247      0.080181      0.246746          0.178129
# std        0.479944      0.085157      0.310922          0.304266
# min        0.000000      0.022500      0.000000          0.000001
# 25%        0.000000      0.034800      0.004280          0.000088
# 50%        1.000000      0.047100      0.081450          0.003920
# 75%        1.000000      0.083100      0.432250          0.201000
# max        1.000000      0.955000      0.996000          0.996000
#
#            liveness       valence         tempo  duration_in_min/ms  \
# count  14396.000000  14396.000000  14396.000000        1.439600e+04
# mean       0.195782      0.486379    122.695372        2.000942e+05
# std        0.159258      0.239476     29.538490        1.116891e+05
# min        0.011900      0.021500     30.557000        5.016500e-01
# 25%        0.097275      0.299000     99.799000        1.654458e+05
# 50%        0.129000      0.480500    120.060000        2.089410e+05
# 75%        0.256000      0.672000    141.988250        2.522470e+05
# max        0.992000      0.986000    217.416000        1.477187e+06
#
#        time_signature         class
# count    14396.000000  14396.000000
# mean         3.924354      6.695679
# std          0.359520      3.206170
# min          1.000000      0.000000
# 25%          4.000000      5.000000
# 50%          4.000000      8.000000
# 75%          4.000000     10.000000
# max          5.000000     10.000000

# %% [markdown]
# Working on duration_in_min/ms
#
# Not all of the values in 'duration_in_min/ms' are in Millisecond, some of them are in minutes

# %%
#THere are 2075 values that are in minutes
train_set[train_set['duration_in_min/ms'] <=40]['duration_in_min/ms'].sort_values(ascending=False)
# train_set.loc[(train_set['duration_in_min/ms'] < 30)]['duration_in_min/ms'].sort_values(ascending=False) Same output
# Out:
# 4882     29.886000
# 12978    23.291550
# 13709    18.709783
# 13849    16.743783
# 491      13.023283
#            ...
# 6345      0.991983
# 5945      0.979333
# 4437      0.969150
# 5117      0.533917
# 11368     0.501650
# Name: duration_in_min/ms, Length: 2075, dtype: float64

# %%
#We use a variable called condition to make the code below shorter
condition = train_set['duration_in_min/ms'] <=40

# If duration_in_min/ms value is less than 40, then multiply by 60,000
"""train_set[train_set['duration_in_min/ms'] <=40]['duration_in_min/ms'] = 
train_set[train_set['duration_in_min/ms'] <=40]['duration_in_min/ms']*6000
Use >> .loc[row_indexer,col_indexer] = value << instead"""
#This changes the data in 'duration_in_min/ms' column
train_set.loc[condition,'duration_in_min/ms'] = train_set.loc[condition,'duration_in_min/ms']*60000

#To check that are values were changed
(train_set['duration_in_min/ms'] <=40).value_counts()
# Out:
# False    14396
# Name: duration_in_min/ms, dtype: int64

# %% [markdown]
# Renaming 'duration_in_min/ms' column

# %%
train_set.rename(columns={"duration_in_min/ms": "duration_in_ms"},inplace=True)
train_set.columns
# Out:
# Index(['artist_name', 'track_name', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_in_ms',
#        'time_signature', 'class'],
#       dtype='object')

# %% [markdown]
# Checking for unkown/null values

# %%
# train_set.isna().any()
train_set[train_set.columns[train_set.isnull().any()]].isnull().sum()
# Out:
# popularity           333
# key                 1609
# instrumentalness    3541
# dtype: int64

# %% [markdown]
# Checking and dealing with "Class" column duplicates

# %%
train_set[train_set.duplicated(subset = train_set.columns.difference(['class']))]
#Returns duplicates that have different Class values
# Out:
#          artist_name             track_name  popularity  danceability  energy  \
# 600        The Chats     Drunk n Disorderly        47.0         0.509   0.733
# 671     Alice Cooper           School's Out        68.0         0.294   0.745
# 709            Foals              My Number        68.0         0.639   0.715
# 862           Freeds             Fruit Bats        42.0         0.897   0.466
# 1038    Modest Mouse               Float On        72.0         0.649   0.888
# ...              ...                    ...         ...           ...     ...
# 14377        Resolve         Seasick Sailor        43.0         0.468   0.964
# 14379      POORSTACY           Public Enemy         NaN         0.520   0.967
# 14381  Ozzy Osbourne  Mama, I'm Coming Home        69.0         0.282   0.656
# 14384   Jackie Hayes              eye 2 eye        48.0         0.638   0.666
# 14390            M83           Kim & Jessie        45.0         0.492   0.567
#
#         key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 600     9.0    -5.909     1       0.1260      0.016500               NaN
# 671     5.0    -9.138     1       0.0461      0.050000          0.125000
# 709     6.0    -8.954     0       0.0392      0.024300          0.000552
# 862    10.0   -10.180     1       0.0478      0.556000          0.000165
# 1038    6.0    -4.807     1       0.0293      0.013000          0.000002
# ...     ...       ...   ...          ...           ...               ...
# 14377   1.0    -5.384     0       0.0931      0.009140          0.000014
# 14379   3.0    -3.837     0       0.4890      0.002480          0.000003
# 14381   8.0    -6.557     1       0.0302      0.010500               NaN
# 14384   4.0    -6.951     0       0.0392      0.007840          0.000067
# 14390   5.0    -6.159     1       0.0327      0.000114          0.536000
#
#        liveness  valence    tempo  duration_in_ms  time_signature  class
# 600      0.4040    0.676  109.736         75760.0               4      6
# 671      0.6760    0.347  134.364        210107.0               4     10
# 709      0.6190    0.813  128.072        238853.0               4     10
# 862      0.1190    0.522  104.944        175313.0               4      9
# 1038     0.0888    0.553  100.975        208467.0               4     10
# ...         ...      ...      ...             ...             ...    ...
# 14377    0.3500    0.185   95.035        219185.0               4      8
# 14379    0.3280    0.477  179.924        149500.0               4      1
# 14381    0.0892    0.242  139.352        251867.0               4     10
# 14384    0.3140    0.651  131.962        185455.0               4      6
# 14390    0.3580    0.245  111.010        323373.0               4     10
#
# [1084 rows x 17 columns]

# %%
train_set[train_set['track_name']=="The Joker"]
#Same track appears twice but has different popularity
# Out:
#             artist_name track_name  popularity  danceability  energy  key  \
# 4179  Steve Miller Band  The Joker        76.0         0.596   0.448  5.0
# 5272  Steve Miller Band  The Joker        12.0         0.596   0.448  5.0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 4179    -9.616     1       0.0396         0.365          0.000005     0.206
# 5272    -9.616     1       0.0396         0.365          0.000005     0.206
#
#       valence   tempo  duration_in_ms  time_signature  class
# 4179    0.796  83.293        264504.0               4     10
# 5272    0.796  83.293        264504.0               4     10

# %%
train_set[train_set.duplicated()]
#Returns duplicates that have exact same values
# Out:
#                        artist_name           track_name  popularity  \
# 5852                   Little Simz                Venom        75.0
# 10163  Joan Jett & The Blackhearts  I Love Rock 'N Roll        74.0
# 13046             Transvision Vamp     I Want Your Love        48.0
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 5852          0.436   0.655  7.0    -8.153     1       0.1590        0.4250
# 10163         0.535   0.716  4.0    -5.025     1       0.0431        0.3260
# 13046         0.465   0.821  4.0   -11.115     1       0.0487        0.0133
#
#        instrumentalness  liveness  valence    tempo  duration_in_ms  \
# 5852                NaN     0.393    0.523  139.712        154749.0
# 10163               NaN     0.659    0.901   94.379        175173.0
# 13046           0.00855     0.447    0.697  149.824        209907.0
#
#        time_signature  class
# 5852                4      9
# 10163               4     10
# 13046               4     10

# %%
# idx1 = pd.Index([2, 1, 3, 4])
# idx2 = pd.Index([3, 4, 5, 6])
# idx2.difference(idx1)
# >> Int64Index([5, 6], dtype='int64')
# idx1.difference(idx2)
# >> Int64Index([1, 2], dtype='int64')

# %%
train_set.duplicated(subset = train_set.columns.difference(['class'])).value_counts()
# Out:
# False    13312
# True      1084
# dtype: int64

# %%
print("Shape of dataset before removing duplicate rows =", train_set.shape)

train_set.drop_duplicates(subset = train_set.columns.difference(['class']), inplace = True, ignore_index = True)
print("Shape of dataset after removing duplicate rows =", train_set.shape)
# Out:
# Shape of dataset before removing duplicate rows = (14396, 17)
# Shape of dataset after removing duplicate rows = (13312, 17)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Artists with most songs in the dataset

# %%
train_set['artist_name'].value_counts().head(5)
# Out:
# Backstreet Boys    58
# Westlife           53
# Britney Spears     47
# Omer Adam          39
# Eyal Golan         38
# Name: artist_name, dtype: int64

# %%
train_set['artist_name'].value_counts().head(40).plot(kind='bar',figsize=(16,12))
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Correlation between numerical attributes and 'class' column

# %%
train_set.corr()['class'].sort_values(ascending=False)
# Out:
# class               1.000000
# energy              0.232102
# loudness            0.184936
# popularity          0.173065
# time_signature      0.047202
# liveness            0.042404
# tempo               0.042246
# duration_in_ms      0.008948
# key                -0.003355
# instrumentalness   -0.027491
# mode               -0.041634
# speechiness        -0.068750
# valence            -0.075240
# danceability       -0.101665
# acousticness       -0.259013
# Name: class, dtype: float64

# %% [markdown]
# Correlation heat map

# %%
sns.heatmap(train_set.corr(), annot=True, cmap='crest',vmax=1, vmin=-0.3 )
sns.set(rc={'figure.figsize':(15,8)})

# %%
sns.countplot(data= train_set, x= train_set["class"])
plt.show()

# %%
train_set.hist(bins=50, figsize=(20, 20),grid=True)
plt.show()
#Energy, Loudness, Speechiness, Acousticness, instrumentalness, duration_in_ms, liveness are all Skewed

# %% [markdown]
# Skewness

# %%
train_set.skew()
#Energy, Loudness, Speechiness, Acousticness, instrumentalness, duration_in_ms, liveness are all Skewed
# Out:
# C:\Users\TQ\AppData\Local\Temp\ipykernel_10332\3459437689.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train_set.skew()
# popularity          0.082546
# danceability       -0.085693
# energy             -0.615383
# key                -0.048348
# loudness           -1.719361
# mode               -0.577062
# speechiness         3.086260
# acousticness        1.036140
# instrumentalness    1.510983
# liveness            2.205829
# valence             0.099441
# tempo               0.384265
# duration_in_ms      3.835998
# time_signature     -4.003748
# class              -0.681687
# dtype: float64

# %%
num_attribs = train_set.select_dtypes(include=[np.number]) # stores all integer/float columns

fig = plt.figure(figsize=(10, 10))
for i,col in enumerate(num_attribs.columns, 1): 
    ax = plt.subplot(5,3,i) # creates 3 subplots in one single row
    sns.boxplot(data = num_attribs, x=num_attribs[col])
    ax.set_xlabel(None)
    ax.set_title(f'Distribution of {col}')
    plt.tight_layout(w_pad=2)
plt.show()

# %%
# faced an issue with energy and duration_in_ms Skewness

# %%
train_set["loudness"] = np.cbrt(train_set["loudness"]) # cube root transform
train_set["speechiness"] = np.reciprocal(train_set["speechiness"]) # reciprocal transform
train_set["acousticness"] = np.cbrt(train_set["acousticness"]) # cube root transform
train_set["instrumentalness"] = np.log(train_set["instrumentalness"]) # log transform
train_set["liveness"] = np.log(train_set["liveness"]) # log transform

# %%
train_set.skew()
# Out:
# C:\Users\TQ\AppData\Local\Temp\ipykernel_10332\1115403286.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train_set.skew()
# popularity          0.082546
# danceability       -0.085693
# energy             -0.615383
# key                -0.048348
# loudness           -0.215996
# mode               -0.577062
# speechiness        -0.100035
# acousticness        0.140229
# instrumentalness   -0.201644
# liveness            0.504727
# valence             0.099441
# tempo               0.384265
# duration_in_ms      3.835998
# time_signature     -4.003748
# class              -0.681687
# dtype: float64

# %%
# train_set["liveness"].hist()
# cbrt, reciprocal, log, sqrt
# lou = np.log(train_set["liveness"])
# lou.hist()
# train_set["loudness"].hist()

# %%
# for col in train_set.select_dtypes(include=[np.number]).columns: 
#     if col == "class":
#         continue
    
#     ax = sns.lmplot(data=train_set, x='class', y=col) #implot looks better than scatterplot
#     plt.title(f"class Vs. {col}")
#     plt.show()

# %%
#After Skewness 

num_attribs = train_set.select_dtypes(include=[np.number]) # stores all integer/float columns
fig = plt.figure(figsize=(10, 10))
for i,col in enumerate(num_attribs.columns, 1): 
    ax = plt.subplot(5,3,i) # creates 3 subplots in one single row
    sns.boxplot(data = num_attribs, x=num_attribs[col])
    ax.set_xlabel(None)
    ax.set_title(f'Distribution of {col}')
    plt.tight_layout(w_pad=2)
plt.show()

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Splitting the training data

# %%
print('train_set columns',train_set.columns)
print('train_set shape: ',train_set.shape)
# Out:
# train_set columns Index(['artist_name', 'track_name', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_in_ms',
#        'time_signature', 'class'],
#       dtype='object')
# train_set shape:  (13312, 17)

# %%
x = train_set.drop(['class'],axis=1)
y = train_set['class']
x_train, x_test, y_train, y_test = train_test_split(x,y , test_size=0.2, random_state =0)
print('x_train shape: ',x_train.shape)
print('x_test shape: ',x_test.shape)
print('y_train shape: ',y_train.shape)
print('y_test shape: ',y_test.shape)
# Out:
# x_train shape:  (10649, 16)
# x_test shape:  (2663, 16)
# y_train shape:  (10649,)
# y_test shape:  (2663,)

# %% [markdown]
# ## Feature Scaling and Transformation

# %%
from sklearn.preprocessing import OrdinalEncoder,MinMaxScaler

# %%
num_attribs = (x_train.select_dtypes(include=[np.number])).columns
cat_attribs= (x_train.select_dtypes(include=[object])).columns

print("num_attribs are: ", num_attribs,'\n','cat_attribs are: ',cat_attribs)
# Out:
# num_attribs are:  Index(['popularity', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_in_ms', 'time_signature'],
#       dtype='object')
#  cat_attribs are:  Index(['artist_name', 'track_name'], dtype='object')

# %%
train_set.isna().sum()
# Out:
# artist_name            0
# track_name             0
# popularity           314
# danceability           0
# energy                 0
# key                 1489
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness    3335
# liveness               0
# valence                0
# tempo                  0
# duration_in_ms         0
# time_signature         0
# class                  0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values = np.nan, strategy = 'median')

x_train[['popularity','instrumentalness']] = imp.fit_transform(x_train[['popularity','instrumentalness']])
x_test[['popularity','instrumentalness']] = imp.fit_transform(x_test[['popularity','instrumentalness']])

# %%
x_train[train_set.columns[train_set.isnull().any()]].isnull().sum()
# Out:
# popularity             0
# key                 1191
# instrumentalness       0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value = -1)
x_train[['key']]=imp.fit_transform(x_train[['key']])
x_test[['key']]=imp.fit_transform(x_test[['key']])

# %%
num_pipeline = Pipeline([('std_scaler', StandardScaler()),])
#('imputer',SimpleImputer(strategy="median"))
#Simple imputer because there NaN and Zero values
cat_pipeline = Pipeline([
        ("ordinal_encoder", OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)),
        ])

transformer= ColumnTransformer([
    ("num", num_pipeline, num_attribs), 
    ]) #("cat",  cat_pipeline, cat_attribs)

transformed_columns = transformer.fit_transform(x_train)
transformed_columns_test = transformer.transform(x_test)
print('transformed_columns shape is: ', transformed_columns.shape)
print('x_test shape is: ', x_test.shape)
print(transformed_columns)
# Out:
# transformed_columns shape is:  (10649, 14)
# x_test shape is:  (2663, 16)
# [[-0.35216688 -0.90511747  1.17952548 ...  1.10732271 -0.57780764
#    0.21187285]
#  [ 0.28698029  1.37907523 -0.25660383 ...  0.70303133 -0.33532022
#    0.21187285]
#  [-0.41027117 -0.3235776   1.34798639 ... -0.41768119 -0.08583661
#    0.21187285]
#  ...
#  [-0.17785401 -0.41350644 -0.48823759 ...  0.2970458   2.18972717
#    0.21187285]
#  [ 0.57750173  1.25317485 -1.12417755 ...  0.48767129  0.14158031
#    0.21187285]
#  [ 0.34508458 -0.83916965  1.28481355 ...  1.85308648  0.18880747
#    0.21187285]]

# %% [markdown]
# # Training and Evaluating different models

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression,SGDClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score,RepeatedStratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
cv = RepeatedStratifiedKFold(n_splits=2, n_repeats=3, random_state=1)

# %% [markdown]
# Evaluating different Models

# %%
knn = KNeighborsClassifier()
rfc = RandomForestClassifier(n_estimators=1000, random_state=42)
log_reg = LogisticRegression(random_state=42)
sgd_clf = SGDClassifier(random_state=42)
xgb_clf = XGBClassifier() 
models = {'KNN': knn,'RFC':rfc , "log_reg": log_reg,"sgd_clf":sgd_clf,'xgb_clf':xgb_clf}

results = [] #delete this

# models = {"Logistic Regression": LinearRegression(), 
#          "Decision Tree Regressor": DecisionTreeRegressor(random_state=0), 
#          "Random Forest Regressor": RandomForestRegressor(random_state=0),
#          "K Neighbors Regressor": KNeighborsRegressor(),
#          "XGB Regressor()":XGBRegressor()}

for name,model in models.items():
    model.fit(transformed_columns, y_train)
    preds = model.predict(transformed_columns_test)
    cv_score = cross_val_score(model, transformed_columns, y_train, cv=cv, scoring="accuracy")
    model_accuracy= accuracy_score(y_test,preds)
    # model_score = model.score(transformed_columns_test,y_test)
    # results.append(cv_score.mean()) delete this
    
    print(f"Model {name} CV_Score: {cv_score}")
    print(f"Model {name} Model Accuracy: {model_accuracy}")
    # print(f"Model {name} Model Score: {model_score}")
    results.append(cv_score)
plt.boxplot(results, labels=models.keys())
plt.show()

# print(results)
# Out:
# Model KNN CV_Score: [0.3885446  0.38880541 0.3800939  0.38786627 0.37615023 0.38824192]
# Model KNN Model Accuracy: 0.41081487044686443
# Model RFC CV_Score: [0.49408451 0.50638618 0.5029108  0.5039444  0.51061033 0.49417731]
# Model RFC Model Accuracy: 0.5069470521967706
# Model log_reg CV_Score: [0.45032864 0.47126221 0.4599061  0.45848986 0.46197183 0.46187077]
# Model log_reg Model Accuracy: 0.44949305294780323
# Model sgd_clf CV_Score: [0.39211268 0.3985725  0.39061033 0.38767844 0.3799061  0.38767844]
# Model sgd_clf Model Accuracy: 0.3897859556890725
# Model xgb_clf CV_Score: [0.48938967 0.49173554 0.49051643 0.49004508 0.48938967 0.47952667]
# Model xgb_clf Model Accuracy: 0.4716485167104769

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(random_state=42)
model_used = gbc
model_used.fit(transformed_columns, y_train)
preds = model_used.predict(transformed_columns_test)
# preds = cross_val_predict(dt_cla, transformed_columns, y_train)
cv_score = cross_val_score(model_used, transformed_columns, y_train, cv=cv, scoring="accuracy")
model_accuracy= accuracy_score(y_test,preds)
# roc_score = roc_auc_score(y_test, preds, multi_class='ovr') 
# results.append(cv_score.mean())
# print(preds.shape)
print(f"Model {model_used} CV_Score: {cv_score}")
print(f"Model {model_used} Model Accuracy: {model_accuracy}")
# Model Accuracy: 0.48666917010889976
# Out:
# Model GradientBoostingClassifier(random_state=42) CV_Score: [0.48807512 0.50206612 0.49690141 0.49380165 0.497277   0.48553719]
# Model GradientBoostingClassifier(random_state=42) Model Accuracy: 0.48666917010889976

# %%
#DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
dt_cla = DecisionTreeClassifier(max_depth=4, criterion='entropy',random_state=42)
model_used = dt_cla
model_used.fit(transformed_columns, y_train)
preds = model_used.predict(transformed_columns_test)
# preds = cross_val_predict(dt_cla, transformed_columns, y_train)
cv_score = cross_val_score(model_used, transformed_columns, y_train, cv=cv, scoring="accuracy")
model_accuracy= accuracy_score(y_test,preds)
# roc_score = roc_auc_score(y_test, preds, multi_class='ovr') 
# results.append(cv_score.mean())
# print(preds.shape)
print(f"Model {model_used} CV_Score: {cv_score}")
print(f"Model {model_used} Model Accuracy: {model_accuracy}")
#Model Accuracy: 0.39128802102891475
# Out:
# Model DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=42) CV_Score: [0.39117371 0.3946281  0.40112676 0.38861758 0.39887324 0.39876033]
# Model DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=42) Model Accuracy: 0.39128802102891475

# %%
#RandomForestClassifier
model_used = rfc
model_used.fit(transformed_columns, y_train)
preds = model_used.predict(transformed_columns_test)
cv_score = cross_val_score(model_used, transformed_columns, y_train, cv=cv, scoring="accuracy")
model_accuracy= accuracy_score(y_test,preds)
# roc_score = roc_auc_score(y_test, preds, multi_class='ovr') 
# results.append(cv_score.mean())

print(f"Model {model_used} CV_Score: {cv_score}")
print(f"Model {model_used} Model Accuracy: {model_accuracy}")
#0.5243055555555556
# Out:
# Model RandomForestClassifier(n_estimators=1000, random_state=42) CV_Score: [0.49408451 0.50638618 0.5029108  0.5039444  0.51061033 0.49417731]
# Model RandomForestClassifier(n_estimators=1000, random_state=42) Model Accuracy: 0.5069470521967706

# %%
model = RandomForestClassifier()
n_estimators = [10, 100, 1000]
max_features = ['sqrt', 'log2']
# define grid search
grid = dict(n_estimators=n_estimators,max_features=max_features)
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
cv = RepeatedStratifiedKFold(n_splits=2, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(transformed_columns,y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

# %% [markdown]
# Trying lightgbm

# %%
import lightgbm as ltb
lightgbm_model = ltb.LGBMClassifier(random_state=42)
lightgbm_model.fit(transformed_columns,y_train)
lgbm_pred = lightgbm_model.predict(transformed_columns_test) #_test
accuracy = round(accuracy_score(y_test, lgbm_pred) * 100, 3) #y_test
accuracy
#53.472
# Out:
# 47.953

# %% [markdown]
# Catboost

# %%
from catboost import CatBoostClassifier
model_used = CatBoostClassifier()
model_used.fit(transformed_columns, y_train)
preds = model_used.predict(transformed_columns_test)
cv_score = cross_val_score(model_used, transformed_columns, y_train, cv=cv, scoring="accuracy")
model_accuracy= accuracy_score(y_test,preds)
# roc_score = roc_auc_score(y_test, preds, multi_class='ovr') 
# results.append(cv_score.mean())

print(f"Model {model_used} CV_Score: {cv_score}")
print(f"Model {model_used} Model Accuracy: {model_accuracy}")
# Out:
# Learning rate set to 0.089272
# 0:	learn: 2.2567248	total: 14.9ms	remaining: 14.9s
# 1:	learn: 2.1622634	total: 30.1ms	remaining: 15s
# 2:	learn: 2.0790751	total: 45ms	remaining: 15s
# 3:	learn: 2.0063790	total: 59ms	remaining: 14.7s
# 4:	learn: 1.9491880	total: 72.9ms	remaining: 14.5s
# 5:	learn: 1.9016704	total: 86.4ms	remaining: 14.3s
# 6:	learn: 1.8578436	total: 100ms	remaining: 14.2s
# 7:	learn: 1.8178949	total: 114ms	remaining: 14.1s
# 8:	learn: 1.7892088	total: 127ms	remaining: 14s
# 9:	learn: 1.7586554	total: 141ms	remaining: 14s
# 10:	learn: 1.7330701	total: 155ms	remaining: 13.9s
# 11:	learn: 1.7117147	total: 168ms	remaining: 13.8s
# 12:	learn: 1.6869779	total: 182ms	remaining: 13.8s
# 13:	learn: 1.6676128	total: 197ms	remaining: 13.8s
# 14:	learn: 1.6516721	total: 210ms	remaining: 13.8s
# 15:	learn: 1.6356615	total: 223ms	remaining: 13.7s
# 16:	learn: 1.6181483	total: 238ms	remaining: 13.7s
# 17:	learn: 1.6035644	total: 251ms	remaining: 13.7s
# 18:	learn: 1.5911124	total: 265ms	remaining: 13.7s
# 19:	learn: 1.5805237	total: 277ms	remaining: 13.6s
# 20:	learn: 1.5671729	total: 291ms	remaining: 13.6s
# 21:	learn: 1.5555822	total: 305ms	remaining: 13.5s
# 22:	learn: 1.5466388	total: 318ms	remaining: 13.5s
# 23:	learn: 1.5369612	total: 331ms	remaining: 13.5s
# 24:	learn: 1.5271012	total: 345ms	remaining: 13.4s
# 25:	learn: 1.5182850	total: 358ms	remaining: 13.4s
# 26:	learn: 1.5104934	total: 372ms	remaining: 13.4s
# 27:	learn: 1.5034559	total: 386ms	remaining: 13.4s
# 28:	learn: 1.4937437	total: 399ms	remaining: 13.4s
# 29:	learn: 1.4856662	total: 413ms	remaining: 13.4s
# 30:	learn: 1.4764075	total: 428ms	remaining: 13.4s
# 31:	learn: 1.4710688	total: 442ms	remaining: 13.4s
# 32:	learn: 1.4643478	total: 456ms	remaining: 13.4s
# 33:	learn: 1.4591988	total: 470ms	remaining: 13.3s
# 34:	learn: 1.4521648	total: 483ms	remaining: 13.3s
# 35:	learn: 1.4451326	total: 498ms	remaining: 13.3s
# 36:	learn: 1.4387727	total: 511ms	remaining: 13.3s
# 37:	learn: 1.4346748	total: 525ms	remaining: 13.3s
# 38:	learn: 1.4281042	total: 539ms	remaining: 13.3s
# 39:	learn: 1.4240497	total: 552ms	remaining: 13.2s
# 40:	learn: 1.4204936	total: 565ms	remaining: 13.2s
# 41:	learn: 1.4157661	total: 579ms	remaining: 13.2s
# 42:	learn: 1.4123650	total: 593ms	remaining: 13.2s
# 43:	learn: 1.4087794	total: 606ms	remaining: 13.2s
# 44:	learn: 1.4037447	total: 619ms	remaining: 13.1s
# 45:	learn: 1.3991802	total: 633ms	remaining: 13.1s
# 46:	learn: 1.3931962	total: 648ms	remaining: 13.1s
# 47:	learn: 1.3885390	total: 661ms	remaining: 13.1s
# 48:	learn: 1.3852199	total: 674ms	remaining: 13.1s
# 49:	learn: 1.3808869	total: 688ms	remaining: 13.1s
# 50:	learn: 1.3765183	total: 702ms	remaining: 13.1s
# 51:	learn: 1.3726543	total: 715ms	remaining: 13s
# 52:	learn: 1.3695649	total: 728ms	remaining: 13s
# 53:	learn: 1.3663440	total: 743ms	remaining: 13s
# 54:	learn: 1.3625860	total: 756ms	remaining: 13s
# 55:	learn: 1.3597951	total: 770ms	remaining: 13s
# 56:	learn: 1.3568053	total: 783ms	remaining: 13s
# 57:	learn: 1.3534869	total: 796ms	remaining: 12.9s
# 58:	learn: 1.3502019	total: 809ms	remaining: 12.9s
# 59:	learn: 1.3469592	total: 822ms	remaining: 12.9s
# 60:	learn: 1.3441624	total: 835ms	remaining: 12.9s
# 61:	learn: 1.3404450	total: 849ms	remaining: 12.8s
# 62:	learn: 1.3375000	total: 862ms	remaining: 12.8s
# 63:	learn: 1.3347603	total: 875ms	remaining: 12.8s
# 64:	learn: 1.3320373	total: 888ms	remaining: 12.8s
# 65:	learn: 1.3286809	total: 901ms	remaining: 12.7s
# 66:	learn: 1.3262006	total: 914ms	remaining: 12.7s
# 67:	learn: 1.3239844	total: 931ms	remaining: 12.8s
# 68:	learn: 1.3214693	total: 947ms	remaining: 12.8s
# 69:	learn: 1.3189156	total: 964ms	remaining: 12.8s
# 70:	learn: 1.3166831	total: 979ms	remaining: 12.8s
# 71:	learn: 1.3137164	total: 996ms	remaining: 12.8s
# 72:	learn: 1.3117163	total: 1.01s	remaining: 12.9s
# 73:	learn: 1.3102528	total: 1.03s	remaining: 12.9s
# 74:	learn: 1.3089141	total: 1.05s	remaining: 12.9s
# 75:	learn: 1.3072505	total: 1.06s	remaining: 12.9s
# 76:	learn: 1.3052639	total: 1.08s	remaining: 12.9s
# 77:	learn: 1.3022745	total: 1.1s	remaining: 13s
# 78:	learn: 1.2996189	total: 1.11s	remaining: 12.9s
# 79:	learn: 1.2963169	total: 1.12s	remaining: 12.9s
# 80:	learn: 1.2937934	total: 1.14s	remaining: 12.9s
# 81:	learn: 1.2918539	total: 1.15s	remaining: 12.9s
# 82:	learn: 1.2890348	total: 1.17s	remaining: 12.9s
# 83:	learn: 1.2874555	total: 1.18s	remaining: 12.9s
# 84:	learn: 1.2850387	total: 1.19s	remaining: 12.8s
# 85:	learn: 1.2822129	total: 1.2s	remaining: 12.8s
# 86:	learn: 1.2800095	total: 1.22s	remaining: 12.8s
# 87:	learn: 1.2774043	total: 1.23s	remaining: 12.8s
# 88:	learn: 1.2752857	total: 1.24s	remaining: 12.7s
# 89:	learn: 1.2727725	total: 1.26s	remaining: 12.7s
# 90:	learn: 1.2709207	total: 1.27s	remaining: 12.7s
# 91:	learn: 1.2695056	total: 1.28s	remaining: 12.7s
# 92:	learn: 1.2674296	total: 1.3s	remaining: 12.6s
# 93:	learn: 1.2653221	total: 1.31s	remaining: 12.6s
# 94:	learn: 1.2632293	total: 1.32s	remaining: 12.6s
# 95:	learn: 1.2610113	total: 1.33s	remaining: 12.6s
# 96:	learn: 1.2590982	total: 1.35s	remaining: 12.6s
# 97:	learn: 1.2571749	total: 1.36s	remaining: 12.5s
# 98:	learn: 1.2556800	total: 1.37s	remaining: 12.5s
# 99:	learn: 1.2542001	total: 1.39s	remaining: 12.5s
# 100:	learn: 1.2530109	total: 1.4s	remaining: 12.5s
# 101:	learn: 1.2516329	total: 1.41s	remaining: 12.4s
# 102:	learn: 1.2496878	total: 1.43s	remaining: 12.4s
# 103:	learn: 1.2482273	total: 1.44s	remaining: 12.4s
# 104:	learn: 1.2463594	total: 1.45s	remaining: 12.4s
# 105:	learn: 1.2451168	total: 1.47s	remaining: 12.4s
# 106:	learn: 1.2430027	total: 1.48s	remaining: 12.4s
# 107:	learn: 1.2407298	total: 1.49s	remaining: 12.3s
# 108:	learn: 1.2388915	total: 1.51s	remaining: 12.3s
# 109:	learn: 1.2370224	total: 1.52s	remaining: 12.3s
# 110:	learn: 1.2354639	total: 1.53s	remaining: 12.3s
# 111:	learn: 1.2334474	total: 1.55s	remaining: 12.3s
# 112:	learn: 1.2318341	total: 1.56s	remaining: 12.2s
# 113:	learn: 1.2301212	total: 1.57s	remaining: 12.2s
# 114:	learn: 1.2278314	total: 1.58s	remaining: 12.2s
# 115:	learn: 1.2263761	total: 1.6s	remaining: 12.2s
# 116:	learn: 1.2248635	total: 1.61s	remaining: 12.2s
# 117:	learn: 1.2232206	total: 1.62s	remaining: 12.1s
# 118:	learn: 1.2218883	total: 1.64s	remaining: 12.1s
# 119:	learn: 1.2206795	total: 1.65s	remaining: 12.1s
# 120:	learn: 1.2193966	total: 1.66s	remaining: 12.1s
# 121:	learn: 1.2178540	total: 1.68s	remaining: 12.1s
# 122:	learn: 1.2167376	total: 1.69s	remaining: 12.1s
# 123:	learn: 1.2156601	total: 1.7s	remaining: 12s
# 124:	learn: 1.2134001	total: 1.72s	remaining: 12s
# 125:	learn: 1.2119402	total: 1.73s	remaining: 12s
# 126:	learn: 1.2103166	total: 1.74s	remaining: 12s
# 127:	learn: 1.2089974	total: 1.76s	remaining: 12s
# 128:	learn: 1.2070720	total: 1.77s	remaining: 12s
# 129:	learn: 1.2053344	total: 1.78s	remaining: 11.9s
# 130:	learn: 1.2041922	total: 1.8s	remaining: 11.9s
# 131:	learn: 1.2027020	total: 1.81s	remaining: 11.9s
# 132:	learn: 1.2004984	total: 1.82s	remaining: 11.9s
# 133:	learn: 1.1989922	total: 1.84s	remaining: 11.9s
# 134:	learn: 1.1970668	total: 1.85s	remaining: 11.9s
# 135:	learn: 1.1958399	total: 1.86s	remaining: 11.8s
# 136:	learn: 1.1950699	total: 1.88s	remaining: 11.8s
# 137:	learn: 1.1934713	total: 1.89s	remaining: 11.8s
# 138:	learn: 1.1922108	total: 1.9s	remaining: 11.8s
# 139:	learn: 1.1903535	total: 1.92s	remaining: 11.8s
# 140:	learn: 1.1886627	total: 1.93s	remaining: 11.8s
# 141:	learn: 1.1870734	total: 1.94s	remaining: 11.7s
# 142:	learn: 1.1856815	total: 1.96s	remaining: 11.7s
# 143:	learn: 1.1844697	total: 1.97s	remaining: 11.7s
# 144:	learn: 1.1829018	total: 1.98s	remaining: 11.7s
# 145:	learn: 1.1812679	total: 2s	remaining: 11.7s
# 146:	learn: 1.1792297	total: 2.01s	remaining: 11.7s
# 147:	learn: 1.1784076	total: 2.02s	remaining: 11.7s
# 148:	learn: 1.1772295	total: 2.04s	remaining: 11.6s
# 149:	learn: 1.1759948	total: 2.05s	remaining: 11.6s
# 150:	learn: 1.1745006	total: 2.06s	remaining: 11.6s
# 151:	learn: 1.1734026	total: 2.08s	remaining: 11.6s
# 152:	learn: 1.1725115	total: 2.09s	remaining: 11.6s
# 153:	learn: 1.1712904	total: 2.1s	remaining: 11.6s
# 154:	learn: 1.1699974	total: 2.12s	remaining: 11.5s
# 155:	learn: 1.1687521	total: 2.13s	remaining: 11.5s
# 156:	learn: 1.1674225	total: 2.15s	remaining: 11.5s
# 157:	learn: 1.1663937	total: 2.16s	remaining: 11.5s
# 158:	learn: 1.1654528	total: 2.17s	remaining: 11.5s
# 159:	learn: 1.1644118	total: 2.19s	remaining: 11.5s
# 160:	learn: 1.1631844	total: 2.2s	remaining: 11.5s
# 161:	learn: 1.1620812	total: 2.21s	remaining: 11.4s
# 162:	learn: 1.1605364	total: 2.23s	remaining: 11.4s
# 163:	learn: 1.1590448	total: 2.24s	remaining: 11.4s
# 164:	learn: 1.1583464	total: 2.25s	remaining: 11.4s
# 165:	learn: 1.1570760	total: 2.26s	remaining: 11.4s
# 166:	learn: 1.1558256	total: 2.28s	remaining: 11.4s
# 167:	learn: 1.1544907	total: 2.29s	remaining: 11.3s
# 168:	learn: 1.1533885	total: 2.3s	remaining: 11.3s
# 169:	learn: 1.1521772	total: 2.32s	remaining: 11.3s
# 170:	learn: 1.1503031	total: 2.33s	remaining: 11.3s
# 171:	learn: 1.1488262	total: 2.35s	remaining: 11.3s
# 172:	learn: 1.1474884	total: 2.36s	remaining: 11.3s
# 173:	learn: 1.1461283	total: 2.37s	remaining: 11.3s
# 174:	learn: 1.1454127	total: 2.39s	remaining: 11.3s
# 175:	learn: 1.1444559	total: 2.4s	remaining: 11.2s
# 176:	learn: 1.1435127	total: 2.41s	remaining: 11.2s
# 177:	learn: 1.1419558	total: 2.43s	remaining: 11.2s
# 178:	learn: 1.1410582	total: 2.44s	remaining: 11.2s
# 179:	learn: 1.1396959	total: 2.46s	remaining: 11.2s
# 180:	learn: 1.1377936	total: 2.47s	remaining: 11.2s
# 181:	learn: 1.1360139	total: 2.48s	remaining: 11.2s
# 182:	learn: 1.1349886	total: 2.5s	remaining: 11.2s
# 183:	learn: 1.1330784	total: 2.51s	remaining: 11.1s
# 184:	learn: 1.1316424	total: 2.53s	remaining: 11.1s
# 185:	learn: 1.1303608	total: 2.54s	remaining: 11.1s
# 186:	learn: 1.1291542	total: 2.55s	remaining: 11.1s
# 187:	learn: 1.1273645	total: 2.57s	remaining: 11.1s
# 188:	learn: 1.1262317	total: 2.58s	remaining: 11.1s
# 189:	learn: 1.1251825	total: 2.59s	remaining: 11.1s
# 190:	learn: 1.1244478	total: 2.61s	remaining: 11s
# 191:	learn: 1.1236868	total: 2.62s	remaining: 11s
# 192:	learn: 1.1220956	total: 2.63s	remaining: 11s
# 193:	learn: 1.1210210	total: 2.65s	remaining: 11s
# 194:	learn: 1.1196411	total: 2.66s	remaining: 11s
# 195:	learn: 1.1181761	total: 2.67s	remaining: 11s
# 196:	learn: 1.1173974	total: 2.69s	remaining: 10.9s
# 197:	learn: 1.1163062	total: 2.7s	remaining: 10.9s
# 198:	learn: 1.1157354	total: 2.71s	remaining: 10.9s
# 199:	learn: 1.1151181	total: 2.73s	remaining: 10.9s
# 200:	learn: 1.1143279	total: 2.74s	remaining: 10.9s
# 201:	learn: 1.1133068	total: 2.75s	remaining: 10.9s
# 202:	learn: 1.1115217	total: 2.77s	remaining: 10.9s
# 203:	learn: 1.1105295	total: 2.78s	remaining: 10.9s
# 204:	learn: 1.1094229	total: 2.79s	remaining: 10.8s
# 205:	learn: 1.1087126	total: 2.81s	remaining: 10.8s
# 206:	learn: 1.1078195	total: 2.82s	remaining: 10.8s
# 207:	learn: 1.1069378	total: 2.84s	remaining: 10.8s
# 208:	learn: 1.1058262	total: 2.85s	remaining: 10.8s
# 209:	learn: 1.1044865	total: 2.86s	remaining: 10.8s
# 210:	learn: 1.1034629	total: 2.88s	remaining: 10.8s
# 211:	learn: 1.1026874	total: 2.89s	remaining: 10.7s
# 212:	learn: 1.1015676	total: 2.91s	remaining: 10.7s
# 213:	learn: 1.1005387	total: 2.92s	remaining: 10.7s
# 214:	learn: 1.0995995	total: 2.93s	remaining: 10.7s
# 215:	learn: 1.0979784	total: 2.95s	remaining: 10.7s
# 216:	learn: 1.0966961	total: 2.96s	remaining: 10.7s
# 217:	learn: 1.0950603	total: 2.97s	remaining: 10.7s
# 218:	learn: 1.0938194	total: 2.99s	remaining: 10.7s
# 219:	learn: 1.0925607	total: 3s	remaining: 10.6s
# 220:	learn: 1.0916136	total: 3.01s	remaining: 10.6s
# 221:	learn: 1.0901815	total: 3.02s	remaining: 10.6s
# 222:	learn: 1.0889859	total: 3.04s	remaining: 10.6s
# 223:	learn: 1.0881179	total: 3.05s	remaining: 10.6s
# 224:	learn: 1.0870463	total: 3.06s	remaining: 10.6s
# 225:	learn: 1.0864372	total: 3.08s	remaining: 10.5s
# 226:	learn: 1.0856375	total: 3.09s	remaining: 10.5s
# 227:	learn: 1.0849998	total: 3.1s	remaining: 10.5s
# 228:	learn: 1.0834714	total: 3.12s	remaining: 10.5s
# 229:	learn: 1.0824548	total: 3.13s	remaining: 10.5s
# 230:	learn: 1.0818045	total: 3.14s	remaining: 10.5s
# 231:	learn: 1.0802731	total: 3.15s	remaining: 10.4s
# 232:	learn: 1.0792860	total: 3.17s	remaining: 10.4s
# 233:	learn: 1.0784278	total: 3.18s	remaining: 10.4s
# 234:	learn: 1.0776423	total: 3.19s	remaining: 10.4s
# 235:	learn: 1.0762124	total: 3.21s	remaining: 10.4s
# 236:	learn: 1.0755770	total: 3.22s	remaining: 10.4s
# 237:	learn: 1.0747880	total: 3.23s	remaining: 10.4s
# 238:	learn: 1.0739890	total: 3.25s	remaining: 10.3s
# 239:	learn: 1.0726205	total: 3.26s	remaining: 10.3s
# 240:	learn: 1.0719614	total: 3.27s	remaining: 10.3s
# 241:	learn: 1.0708341	total: 3.29s	remaining: 10.3s
# 242:	learn: 1.0699577	total: 3.3s	remaining: 10.3s
# 243:	learn: 1.0688542	total: 3.31s	remaining: 10.3s
# 244:	learn: 1.0676881	total: 3.33s	remaining: 10.3s
# 245:	learn: 1.0664649	total: 3.34s	remaining: 10.2s
# 246:	learn: 1.0651922	total: 3.35s	remaining: 10.2s
# 247:	learn: 1.0645220	total: 3.37s	remaining: 10.2s
# 248:	learn: 1.0635380	total: 3.38s	remaining: 10.2s
# 249:	learn: 1.0624186	total: 3.39s	remaining: 10.2s
# 250:	learn: 1.0611402	total: 3.41s	remaining: 10.2s
# 251:	learn: 1.0602101	total: 3.42s	remaining: 10.2s
# 252:	learn: 1.0591602	total: 3.43s	remaining: 10.1s
# 253:	learn: 1.0582028	total: 3.45s	remaining: 10.1s
# 254:	learn: 1.0571498	total: 3.46s	remaining: 10.1s
# 255:	learn: 1.0557747	total: 3.47s	remaining: 10.1s
# 256:	learn: 1.0544145	total: 3.49s	remaining: 10.1s
# 257:	learn: 1.0533854	total: 3.5s	remaining: 10.1s
# 258:	learn: 1.0521141	total: 3.51s	remaining: 10s
# 259:	learn: 1.0511060	total: 3.52s	remaining: 10s
# 260:	learn: 1.0502343	total: 3.54s	remaining: 10s
# 261:	learn: 1.0494610	total: 3.55s	remaining: 10s
# 262:	learn: 1.0484635	total: 3.56s	remaining: 9.99s
# 263:	learn: 1.0476740	total: 3.58s	remaining: 9.97s
# 264:	learn: 1.0464573	total: 3.59s	remaining: 9.96s
# 265:	learn: 1.0453020	total: 3.6s	remaining: 9.95s
# 266:	learn: 1.0441050	total: 3.62s	remaining: 9.93s
# 267:	learn: 1.0433181	total: 3.63s	remaining: 9.92s
# 268:	learn: 1.0424496	total: 3.64s	remaining: 9.9s
# 269:	learn: 1.0412461	total: 3.66s	remaining: 9.89s
# 270:	learn: 1.0405006	total: 3.67s	remaining: 9.87s
# 271:	learn: 1.0401189	total: 3.68s	remaining: 9.86s
# 272:	learn: 1.0384364	total: 3.7s	remaining: 9.84s
# 273:	learn: 1.0373168	total: 3.71s	remaining: 9.83s
# 274:	learn: 1.0363881	total: 3.72s	remaining: 9.81s
# 275:	learn: 1.0354402	total: 3.73s	remaining: 9.8s
# 276:	learn: 1.0341771	total: 3.75s	remaining: 9.79s
# 277:	learn: 1.0331866	total: 3.76s	remaining: 9.77s
# 278:	learn: 1.0319706	total: 3.77s	remaining: 9.76s
# 279:	learn: 1.0312533	total: 3.79s	remaining: 9.74s
# 280:	learn: 1.0302406	total: 3.8s	remaining: 9.73s
# 281:	learn: 1.0293566	total: 3.81s	remaining: 9.71s
# 282:	learn: 1.0278517	total: 3.83s	remaining: 9.7s
# 283:	learn: 1.0270466	total: 3.84s	remaining: 9.69s
# 284:	learn: 1.0259596	total: 3.85s	remaining: 9.67s
# 285:	learn: 1.0249656	total: 3.87s	remaining: 9.65s
# 286:	learn: 1.0240325	total: 3.88s	remaining: 9.64s
# 287:	learn: 1.0225378	total: 3.89s	remaining: 9.63s
# 288:	learn: 1.0216078	total: 3.91s	remaining: 9.61s
# 289:	learn: 1.0206274	total: 3.92s	remaining: 9.6s
# 290:	learn: 1.0197894	total: 3.93s	remaining: 9.59s
# 291:	learn: 1.0190964	total: 3.95s	remaining: 9.57s
# 292:	learn: 1.0183942	total: 3.96s	remaining: 9.56s
# 293:	learn: 1.0171246	total: 3.97s	remaining: 9.54s
# 294:	learn: 1.0159926	total: 3.99s	remaining: 9.53s
# 295:	learn: 1.0145141	total: 4s	remaining: 9.51s
# 296:	learn: 1.0136001	total: 4.01s	remaining: 9.5s
# 297:	learn: 1.0124146	total: 4.03s	remaining: 9.49s
# 298:	learn: 1.0111000	total: 4.04s	remaining: 9.47s
# 299:	learn: 1.0102810	total: 4.05s	remaining: 9.46s
# 300:	learn: 1.0093783	total: 4.07s	remaining: 9.44s
# 301:	learn: 1.0087427	total: 4.08s	remaining: 9.43s
# 302:	learn: 1.0076065	total: 4.09s	remaining: 9.41s
# 303:	learn: 1.0066989	total: 4.11s	remaining: 9.4s
# 304:	learn: 1.0057161	total: 4.12s	remaining: 9.38s
# 305:	learn: 1.0046265	total: 4.13s	remaining: 9.37s
# 306:	learn: 1.0039381	total: 4.14s	remaining: 9.36s
# 307:	learn: 1.0033078	total: 4.16s	remaining: 9.34s
# 308:	learn: 1.0028076	total: 4.17s	remaining: 9.33s
# 309:	learn: 1.0016281	total: 4.18s	remaining: 9.31s
# 310:	learn: 1.0008999	total: 4.2s	remaining: 9.3s
# 311:	learn: 1.0000045	total: 4.21s	remaining: 9.29s
# 312:	learn: 0.9993255	total: 4.22s	remaining: 9.27s
# 313:	learn: 0.9989874	total: 4.24s	remaining: 9.26s
# 314:	learn: 0.9980853	total: 4.25s	remaining: 9.25s
# 315:	learn: 0.9977566	total: 4.27s	remaining: 9.23s
# 316:	learn: 0.9970710	total: 4.28s	remaining: 9.22s
# 317:	learn: 0.9956658	total: 4.29s	remaining: 9.2s
# 318:	learn: 0.9951619	total: 4.3s	remaining: 9.19s
# 319:	learn: 0.9937538	total: 4.32s	remaining: 9.18s
# 320:	learn: 0.9929078	total: 4.33s	remaining: 9.16s
# 321:	learn: 0.9915955	total: 4.34s	remaining: 9.15s
# 322:	learn: 0.9908122	total: 4.36s	remaining: 9.13s
# 323:	learn: 0.9890525	total: 4.37s	remaining: 9.12s
# 324:	learn: 0.9880927	total: 4.38s	remaining: 9.11s
# 325:	learn: 0.9872755	total: 4.4s	remaining: 9.09s
# 326:	learn: 0.9862533	total: 4.41s	remaining: 9.07s
# 327:	learn: 0.9853985	total: 4.42s	remaining: 9.06s
# 328:	learn: 0.9844236	total: 4.43s	remaining: 9.05s
# 329:	learn: 0.9835862	total: 4.45s	remaining: 9.03s
# 330:	learn: 0.9824242	total: 4.46s	remaining: 9.02s
# 331:	learn: 0.9816468	total: 4.48s	remaining: 9.01s
# 332:	learn: 0.9810591	total: 4.49s	remaining: 8.99s
# 333:	learn: 0.9803564	total: 4.5s	remaining: 8.98s
# 334:	learn: 0.9797869	total: 4.51s	remaining: 8.96s
# 335:	learn: 0.9791924	total: 4.53s	remaining: 8.95s
# 336:	learn: 0.9781785	total: 4.54s	remaining: 8.93s
# 337:	learn: 0.9766985	total: 4.55s	remaining: 8.92s
# 338:	learn: 0.9756760	total: 4.57s	remaining: 8.9s
# 339:	learn: 0.9750026	total: 4.58s	remaining: 8.89s
# 340:	learn: 0.9743311	total: 4.59s	remaining: 8.88s
# 341:	learn: 0.9737599	total: 4.61s	remaining: 8.86s
# 342:	learn: 0.9728838	total: 4.62s	remaining: 8.85s
# 343:	learn: 0.9723417	total: 4.63s	remaining: 8.83s
# 344:	learn: 0.9718099	total: 4.64s	remaining: 8.82s
# 345:	learn: 0.9708738	total: 4.66s	remaining: 8.81s
# 346:	learn: 0.9706202	total: 4.67s	remaining: 8.79s
# 347:	learn: 0.9696611	total: 4.69s	remaining: 8.78s
# 348:	learn: 0.9689765	total: 4.7s	remaining: 8.77s
# 349:	learn: 0.9677671	total: 4.71s	remaining: 8.75s
# 350:	learn: 0.9668542	total: 4.72s	remaining: 8.74s
# 351:	learn: 0.9665411	total: 4.74s	remaining: 8.72s
# 352:	learn: 0.9658426	total: 4.75s	remaining: 8.71s
# 353:	learn: 0.9652357	total: 4.76s	remaining: 8.69s
# 354:	learn: 0.9644698	total: 4.78s	remaining: 8.68s
# 355:	learn: 0.9636283	total: 4.79s	remaining: 8.67s
# 356:	learn: 0.9630719	total: 4.8s	remaining: 8.65s
# 357:	learn: 0.9624347	total: 4.82s	remaining: 8.64s
# 358:	learn: 0.9615334	total: 4.83s	remaining: 8.62s
# 359:	learn: 0.9610543	total: 4.84s	remaining: 8.61s
# 360:	learn: 0.9600595	total: 4.86s	remaining: 8.59s
# 361:	learn: 0.9595361	total: 4.87s	remaining: 8.58s
# 362:	learn: 0.9583179	total: 4.89s	remaining: 8.58s
# 363:	learn: 0.9575446	total: 4.9s	remaining: 8.56s
# 364:	learn: 0.9565348	total: 4.92s	remaining: 8.55s
# 365:	learn: 0.9555267	total: 4.93s	remaining: 8.54s
# 366:	learn: 0.9542440	total: 4.94s	remaining: 8.52s
# 367:	learn: 0.9534891	total: 4.96s	remaining: 8.51s
# 368:	learn: 0.9524343	total: 4.97s	remaining: 8.49s
# 369:	learn: 0.9512531	total: 4.98s	remaining: 8.48s
# 370:	learn: 0.9506941	total: 4.99s	remaining: 8.47s
# 371:	learn: 0.9494307	total: 5.01s	remaining: 8.45s
# 372:	learn: 0.9486690	total: 5.02s	remaining: 8.44s
# 373:	learn: 0.9476114	total: 5.03s	remaining: 8.42s
# 374:	learn: 0.9465448	total: 5.05s	remaining: 8.41s
# 375:	learn: 0.9455445	total: 5.06s	remaining: 8.4s
# 376:	learn: 0.9448042	total: 5.07s	remaining: 8.38s
# 377:	learn: 0.9439426	total: 5.09s	remaining: 8.37s
# 378:	learn: 0.9432838	total: 5.1s	remaining: 8.36s
# 379:	learn: 0.9421118	total: 5.11s	remaining: 8.34s
# 380:	learn: 0.9413868	total: 5.13s	remaining: 8.33s
# 381:	learn: 0.9405961	total: 5.14s	remaining: 8.32s
# 382:	learn: 0.9396667	total: 5.15s	remaining: 8.3s
# 383:	learn: 0.9389033	total: 5.17s	remaining: 8.29s
# 384:	learn: 0.9382918	total: 5.18s	remaining: 8.27s
# 385:	learn: 0.9378842	total: 5.19s	remaining: 8.26s
# 386:	learn: 0.9372852	total: 5.2s	remaining: 8.24s
# 387:	learn: 0.9361909	total: 5.22s	remaining: 8.23s
# 388:	learn: 0.9353851	total: 5.23s	remaining: 8.21s
# 389:	learn: 0.9343999	total: 5.24s	remaining: 8.2s
# 390:	learn: 0.9334220	total: 5.25s	remaining: 8.19s
# 391:	learn: 0.9327719	total: 5.27s	remaining: 8.17s
# 392:	learn: 0.9320800	total: 5.28s	remaining: 8.16s
# 393:	learn: 0.9310486	total: 5.29s	remaining: 8.14s
# 394:	learn: 0.9303606	total: 5.31s	remaining: 8.13s
# 395:	learn: 0.9296568	total: 5.32s	remaining: 8.12s
# 396:	learn: 0.9286414	total: 5.34s	remaining: 8.1s
# 397:	learn: 0.9277622	total: 5.35s	remaining: 8.09s
# 398:	learn: 0.9269322	total: 5.36s	remaining: 8.08s
# 399:	learn: 0.9261138	total: 5.38s	remaining: 8.06s
# 400:	learn: 0.9254265	total: 5.39s	remaining: 8.05s
# 401:	learn: 0.9246875	total: 5.4s	remaining: 8.04s
# 402:	learn: 0.9242357	total: 5.42s	remaining: 8.02s
# 403:	learn: 0.9235985	total: 5.43s	remaining: 8.01s
# 404:	learn: 0.9230229	total: 5.44s	remaining: 7.99s
# 405:	learn: 0.9218522	total: 5.45s	remaining: 7.98s
# 406:	learn: 0.9214530	total: 5.47s	remaining: 7.97s
# 407:	learn: 0.9209245	total: 5.48s	remaining: 7.95s
# 408:	learn: 0.9201168	total: 5.49s	remaining: 7.94s
# 409:	learn: 0.9195256	total: 5.51s	remaining: 7.92s
# 410:	learn: 0.9188384	total: 5.52s	remaining: 7.91s
# 411:	learn: 0.9182813	total: 5.53s	remaining: 7.9s
# 412:	learn: 0.9173584	total: 5.55s	remaining: 7.88s
# 413:	learn: 0.9167871	total: 5.56s	remaining: 7.87s
# 414:	learn: 0.9160827	total: 5.57s	remaining: 7.85s
# 415:	learn: 0.9153452	total: 5.58s	remaining: 7.84s
# 416:	learn: 0.9150163	total: 5.6s	remaining: 7.83s
# 417:	learn: 0.9143167	total: 5.61s	remaining: 7.81s
# 418:	learn: 0.9137689	total: 5.62s	remaining: 7.8s
# 419:	learn: 0.9127932	total: 5.64s	remaining: 7.78s
# 420:	learn: 0.9122761	total: 5.65s	remaining: 7.77s
# 421:	learn: 0.9118998	total: 5.67s	remaining: 7.76s
# 422:	learn: 0.9110404	total: 5.68s	remaining: 7.75s
# 423:	learn: 0.9104083	total: 5.69s	remaining: 7.73s
# 424:	learn: 0.9095931	total: 5.7s	remaining: 7.72s
# 425:	learn: 0.9092012	total: 5.72s	remaining: 7.7s
# 426:	learn: 0.9086901	total: 5.73s	remaining: 7.69s
# 427:	learn: 0.9077234	total: 5.74s	remaining: 7.68s
# 428:	learn: 0.9069684	total: 5.76s	remaining: 7.66s
# 429:	learn: 0.9058080	total: 5.77s	remaining: 7.65s
# 430:	learn: 0.9052990	total: 5.78s	remaining: 7.63s
# 431:	learn: 0.9044532	total: 5.79s	remaining: 7.62s
# 432:	learn: 0.9037765	total: 5.81s	remaining: 7.61s
# 433:	learn: 0.9033444	total: 5.82s	remaining: 7.59s
# 434:	learn: 0.9030857	total: 5.83s	remaining: 7.58s
# 435:	learn: 0.9021434	total: 5.85s	remaining: 7.56s
# 436:	learn: 0.9018610	total: 5.86s	remaining: 7.55s
# 437:	learn: 0.9012496	total: 5.87s	remaining: 7.54s
# 438:	learn: 0.9006393	total: 5.89s	remaining: 7.52s
# 439:	learn: 0.9000136	total: 5.9s	remaining: 7.51s
# 440:	learn: 0.8989515	total: 5.91s	remaining: 7.49s
# 441:	learn: 0.8979479	total: 5.93s	remaining: 7.48s
# 442:	learn: 0.8974015	total: 5.94s	remaining: 7.47s
# 443:	learn: 0.8967054	total: 5.95s	remaining: 7.46s
# 444:	learn: 0.8960952	total: 5.97s	remaining: 7.44s
# 445:	learn: 0.8954472	total: 5.98s	remaining: 7.43s
# 446:	learn: 0.8950610	total: 6s	remaining: 7.42s
# 447:	learn: 0.8942318	total: 6.01s	remaining: 7.4s
# 448:	learn: 0.8936377	total: 6.02s	remaining: 7.39s
# 449:	learn: 0.8925685	total: 6.03s	remaining: 7.38s
# 450:	learn: 0.8919056	total: 6.05s	remaining: 7.36s
# 451:	learn: 0.8912206	total: 6.06s	remaining: 7.35s
# 452:	learn: 0.8903737	total: 6.07s	remaining: 7.33s
# 453:	learn: 0.8898030	total: 6.08s	remaining: 7.32s
# 454:	learn: 0.8894203	total: 6.1s	remaining: 7.3s
# 455:	learn: 0.8887856	total: 6.11s	remaining: 7.29s
# 456:	learn: 0.8881179	total: 6.12s	remaining: 7.28s
# 457:	learn: 0.8878249	total: 6.14s	remaining: 7.26s
# 458:	learn: 0.8873372	total: 6.15s	remaining: 7.25s
# 459:	learn: 0.8863710	total: 6.16s	remaining: 7.24s
# 460:	learn: 0.8856511	total: 6.18s	remaining: 7.22s
# 461:	learn: 0.8851822	total: 6.19s	remaining: 7.21s
# 462:	learn: 0.8845504	total: 6.2s	remaining: 7.19s
# 463:	learn: 0.8832833	total: 6.22s	remaining: 7.18s
# 464:	learn: 0.8825803	total: 6.23s	remaining: 7.17s
# 465:	learn: 0.8820602	total: 6.24s	remaining: 7.15s
# 466:	learn: 0.8813915	total: 6.25s	remaining: 7.14s
# 467:	learn: 0.8807894	total: 6.27s	remaining: 7.12s
# 468:	learn: 0.8800957	total: 6.28s	remaining: 7.11s
# 469:	learn: 0.8791295	total: 6.29s	remaining: 7.1s
# 470:	learn: 0.8784782	total: 6.3s	remaining: 7.08s
# 471:	learn: 0.8775507	total: 6.32s	remaining: 7.07s
# 472:	learn: 0.8766448	total: 6.33s	remaining: 7.05s
# 473:	learn: 0.8761293	total: 6.34s	remaining: 7.04s
# 474:	learn: 0.8750056	total: 6.36s	remaining: 7.03s
# 475:	learn: 0.8744393	total: 6.38s	remaining: 7.02s
# 476:	learn: 0.8734293	total: 6.39s	remaining: 7s
# 477:	learn: 0.8729737	total: 6.4s	remaining: 6.99s
# 478:	learn: 0.8718229	total: 6.42s	remaining: 6.98s
# 479:	learn: 0.8713040	total: 6.43s	remaining: 6.96s
# 480:	learn: 0.8704037	total: 6.44s	remaining: 6.95s
# 481:	learn: 0.8695593	total: 6.45s	remaining: 6.94s
# 482:	learn: 0.8686856	total: 6.47s	remaining: 6.92s
# 483:	learn: 0.8680823	total: 6.48s	remaining: 6.91s
# 484:	learn: 0.8675448	total: 6.49s	remaining: 6.89s
# 485:	learn: 0.8668730	total: 6.51s	remaining: 6.88s
# 486:	learn: 0.8664982	total: 6.52s	remaining: 6.87s
# 487:	learn: 0.8657724	total: 6.53s	remaining: 6.85s
# 488:	learn: 0.8653228	total: 6.54s	remaining: 6.84s
# 489:	learn: 0.8648252	total: 6.56s	remaining: 6.83s
# 490:	learn: 0.8642692	total: 6.57s	remaining: 6.81s
# 491:	learn: 0.8637633	total: 6.58s	remaining: 6.8s
# 492:	learn: 0.8630335	total: 6.6s	remaining: 6.78s
# 493:	learn: 0.8621990	total: 6.61s	remaining: 6.77s
# 494:	learn: 0.8613702	total: 6.62s	remaining: 6.76s
# 495:	learn: 0.8605598	total: 6.64s	remaining: 6.74s
# 496:	learn: 0.8598863	total: 6.65s	remaining: 6.73s
# 497:	learn: 0.8595623	total: 6.66s	remaining: 6.71s
# 498:	learn: 0.8586511	total: 6.68s	remaining: 6.7s
# 499:	learn: 0.8577061	total: 6.69s	remaining: 6.69s
# 500:	learn: 0.8568754	total: 6.7s	remaining: 6.67s
# 501:	learn: 0.8562409	total: 6.72s	remaining: 6.66s
# 502:	learn: 0.8559524	total: 6.73s	remaining: 6.65s
# 503:	learn: 0.8550578	total: 6.74s	remaining: 6.63s
# 504:	learn: 0.8544236	total: 6.75s	remaining: 6.62s
# 505:	learn: 0.8534933	total: 6.77s	remaining: 6.61s
# 506:	learn: 0.8531337	total: 6.78s	remaining: 6.59s
# 507:	learn: 0.8522705	total: 6.79s	remaining: 6.58s
# 508:	learn: 0.8515534	total: 6.81s	remaining: 6.57s
# 509:	learn: 0.8511136	total: 6.82s	remaining: 6.55s
# 510:	learn: 0.8506497	total: 6.83s	remaining: 6.54s
# 511:	learn: 0.8502107	total: 6.85s	remaining: 6.53s
# 512:	learn: 0.8499933	total: 6.86s	remaining: 6.51s
# 513:	learn: 0.8493088	total: 6.87s	remaining: 6.5s
# 514:	learn: 0.8483881	total: 6.89s	remaining: 6.49s
# 515:	learn: 0.8480076	total: 6.9s	remaining: 6.47s
# 516:	learn: 0.8471100	total: 6.91s	remaining: 6.46s
# 517:	learn: 0.8462877	total: 6.93s	remaining: 6.45s
# 518:	learn: 0.8455554	total: 6.94s	remaining: 6.43s
# 519:	learn: 0.8450796	total: 6.95s	remaining: 6.42s
# 520:	learn: 0.8442716	total: 6.97s	remaining: 6.4s
# 521:	learn: 0.8434269	total: 6.98s	remaining: 6.39s
# 522:	learn: 0.8427575	total: 6.99s	remaining: 6.38s
# 523:	learn: 0.8419953	total: 7.01s	remaining: 6.36s
# 524:	learn: 0.8411413	total: 7.02s	remaining: 6.35s
# 525:	learn: 0.8406783	total: 7.03s	remaining: 6.34s
# 526:	learn: 0.8399955	total: 7.04s	remaining: 6.32s
# 527:	learn: 0.8390336	total: 7.06s	remaining: 6.31s
# 528:	learn: 0.8387014	total: 7.07s	remaining: 6.3s
# 529:	learn: 0.8380499	total: 7.08s	remaining: 6.28s
# 530:	learn: 0.8375551	total: 7.1s	remaining: 6.27s
# 531:	learn: 0.8369417	total: 7.11s	remaining: 6.25s
# 532:	learn: 0.8362055	total: 7.12s	remaining: 6.24s
# 533:	learn: 0.8354467	total: 7.14s	remaining: 6.23s
# 534:	learn: 0.8345165	total: 7.15s	remaining: 6.22s
# 535:	learn: 0.8336885	total: 7.17s	remaining: 6.2s
# 536:	learn: 0.8331355	total: 7.18s	remaining: 6.19s
# 537:	learn: 0.8326889	total: 7.19s	remaining: 6.17s
# 538:	learn: 0.8321419	total: 7.2s	remaining: 6.16s
# 539:	learn: 0.8317327	total: 7.22s	remaining: 6.15s
# 540:	learn: 0.8310790	total: 7.23s	remaining: 6.13s
# 541:	learn: 0.8302416	total: 7.24s	remaining: 6.12s
# 542:	learn: 0.8295834	total: 7.26s	remaining: 6.11s
# 543:	learn: 0.8290710	total: 7.27s	remaining: 6.09s
# 544:	learn: 0.8285121	total: 7.28s	remaining: 6.08s
# 545:	learn: 0.8280866	total: 7.3s	remaining: 6.07s
# 546:	learn: 0.8274714	total: 7.31s	remaining: 6.05s
# 547:	learn: 0.8270498	total: 7.32s	remaining: 6.04s
# 548:	learn: 0.8264875	total: 7.33s	remaining: 6.03s
# 549:	learn: 0.8261889	total: 7.35s	remaining: 6.01s
# 550:	learn: 0.8256180	total: 7.36s	remaining: 6s
# 551:	learn: 0.8251518	total: 7.38s	remaining: 5.99s
# 552:	learn: 0.8244752	total: 7.39s	remaining: 5.97s
# 553:	learn: 0.8236690	total: 7.4s	remaining: 5.96s
# 554:	learn: 0.8230790	total: 7.42s	remaining: 5.95s
# 555:	learn: 0.8223789	total: 7.43s	remaining: 5.93s
# 556:	learn: 0.8212048	total: 7.44s	remaining: 5.92s
# 557:	learn: 0.8205664	total: 7.45s	remaining: 5.91s
# 558:	learn: 0.8197426	total: 7.47s	remaining: 5.89s
# 559:	learn: 0.8188321	total: 7.48s	remaining: 5.88s
# 560:	learn: 0.8180264	total: 7.49s	remaining: 5.87s
# 561:	learn: 0.8174658	total: 7.51s	remaining: 5.85s
# 562:	learn: 0.8165320	total: 7.52s	remaining: 5.84s
# 563:	learn: 0.8153982	total: 7.53s	remaining: 5.82s
# 564:	learn: 0.8146236	total: 7.55s	remaining: 5.81s
# 565:	learn: 0.8137101	total: 7.56s	remaining: 5.8s
# 566:	learn: 0.8132868	total: 7.57s	remaining: 5.78s
# 567:	learn: 0.8126583	total: 7.59s	remaining: 5.77s
# 568:	learn: 0.8120274	total: 7.6s	remaining: 5.76s
# 569:	learn: 0.8117386	total: 7.61s	remaining: 5.74s
# 570:	learn: 0.8111416	total: 7.63s	remaining: 5.73s
# 571:	learn: 0.8100267	total: 7.64s	remaining: 5.72s
# 572:	learn: 0.8094339	total: 7.65s	remaining: 5.7s
# 573:	learn: 0.8089576	total: 7.67s	remaining: 5.69s
# 574:	learn: 0.8082442	total: 7.68s	remaining: 5.68s
# 575:	learn: 0.8079163	total: 7.69s	remaining: 5.66s
# 576:	learn: 0.8074011	total: 7.71s	remaining: 5.65s
# 577:	learn: 0.8071437	total: 7.72s	remaining: 5.64s
# 578:	learn: 0.8066344	total: 7.73s	remaining: 5.62s
# 579:	learn: 0.8062492	total: 7.75s	remaining: 5.61s
# 580:	learn: 0.8056518	total: 7.76s	remaining: 5.59s
# 581:	learn: 0.8051219	total: 7.77s	remaining: 5.58s
# 582:	learn: 0.8045023	total: 7.78s	remaining: 5.57s
# 583:	learn: 0.8040570	total: 7.8s	remaining: 5.55s
# 584:	learn: 0.8034767	total: 7.81s	remaining: 5.54s
# 585:	learn: 0.8031603	total: 7.83s	remaining: 5.53s
# 586:	learn: 0.8024665	total: 7.84s	remaining: 5.51s
# 587:	learn: 0.8017960	total: 7.85s	remaining: 5.5s
# 588:	learn: 0.8014302	total: 7.86s	remaining: 5.49s
# 589:	learn: 0.8006573	total: 7.88s	remaining: 5.47s
# 590:	learn: 0.8002286	total: 7.89s	remaining: 5.46s
# 591:	learn: 0.7996155	total: 7.91s	remaining: 5.45s
# 592:	learn: 0.7988404	total: 7.92s	remaining: 5.43s
# 593:	learn: 0.7980304	total: 7.93s	remaining: 5.42s
# 594:	learn: 0.7974847	total: 7.95s	remaining: 5.41s
# 595:	learn: 0.7963869	total: 7.96s	remaining: 5.39s
# 596:	learn: 0.7959415	total: 7.97s	remaining: 5.38s
# 597:	learn: 0.7955208	total: 7.98s	remaining: 5.37s
# 598:	learn: 0.7950522	total: 8s	remaining: 5.35s
# 599:	learn: 0.7943582	total: 8.01s	remaining: 5.34s
# 600:	learn: 0.7936954	total: 8.02s	remaining: 5.33s
# 601:	learn: 0.7926134	total: 8.04s	remaining: 5.31s
# 602:	learn: 0.7920162	total: 8.05s	remaining: 5.3s
# 603:	learn: 0.7911055	total: 8.06s	remaining: 5.29s
# 604:	learn: 0.7901556	total: 8.08s	remaining: 5.27s
# 605:	learn: 0.7896470	total: 8.09s	remaining: 5.26s
# 606:	learn: 0.7884695	total: 8.1s	remaining: 5.25s
# 607:	learn: 0.7875775	total: 8.12s	remaining: 5.23s
# 608:	learn: 0.7868667	total: 8.13s	remaining: 5.22s
# 609:	learn: 0.7865026	total: 8.14s	remaining: 5.21s
# 610:	learn: 0.7857772	total: 8.16s	remaining: 5.19s
# 611:	learn: 0.7848450	total: 8.17s	remaining: 5.18s
# 612:	learn: 0.7836784	total: 8.18s	remaining: 5.17s
# 613:	learn: 0.7832835	total: 8.2s	remaining: 5.15s
# 614:	learn: 0.7822923	total: 8.21s	remaining: 5.14s
# 615:	learn: 0.7814912	total: 8.22s	remaining: 5.13s
# 616:	learn: 0.7805289	total: 8.24s	remaining: 5.11s
# 617:	learn: 0.7802314	total: 8.25s	remaining: 5.1s
# 618:	learn: 0.7792978	total: 8.26s	remaining: 5.08s
# 619:	learn: 0.7783482	total: 8.28s	remaining: 5.07s
# 620:	learn: 0.7780440	total: 8.29s	remaining: 5.06s
# 621:	learn: 0.7776647	total: 8.3s	remaining: 5.04s
# 622:	learn: 0.7771778	total: 8.31s	remaining: 5.03s
# 623:	learn: 0.7765383	total: 8.33s	remaining: 5.02s
# 624:	learn: 0.7760331	total: 8.34s	remaining: 5s
# 625:	learn: 0.7753584	total: 8.36s	remaining: 4.99s
# 626:	learn: 0.7745064	total: 8.37s	remaining: 4.98s
# 627:	learn: 0.7740744	total: 8.38s	remaining: 4.96s
# 628:	learn: 0.7736377	total: 8.39s	remaining: 4.95s
# 629:	learn: 0.7730354	total: 8.41s	remaining: 4.94s
# 630:	learn: 0.7722921	total: 8.42s	remaining: 4.92s
# 631:	learn: 0.7713570	total: 8.43s	remaining: 4.91s
# 632:	learn: 0.7706409	total: 8.45s	remaining: 4.9s
# 633:	learn: 0.7702816	total: 8.46s	remaining: 4.88s
# 634:	learn: 0.7695755	total: 8.47s	remaining: 4.87s
# 635:	learn: 0.7690703	total: 8.48s	remaining: 4.86s
# 636:	learn: 0.7687899	total: 8.5s	remaining: 4.84s
# 637:	learn: 0.7678703	total: 8.51s	remaining: 4.83s
# 638:	learn: 0.7672400	total: 8.52s	remaining: 4.82s
# 639:	learn: 0.7668049	total: 8.54s	remaining: 4.8s
# 640:	learn: 0.7663140	total: 8.55s	remaining: 4.79s
# 641:	learn: 0.7657349	total: 8.56s	remaining: 4.78s
# 642:	learn: 0.7651515	total: 8.58s	remaining: 4.76s
# 643:	learn: 0.7643868	total: 8.59s	remaining: 4.75s
# 644:	learn: 0.7636307	total: 8.6s	remaining: 4.74s
# 645:	learn: 0.7628795	total: 8.62s	remaining: 4.72s
# 646:	learn: 0.7620172	total: 8.63s	remaining: 4.71s
# 647:	learn: 0.7615039	total: 8.64s	remaining: 4.69s
# 648:	learn: 0.7606567	total: 8.65s	remaining: 4.68s
# 649:	learn: 0.7594610	total: 8.67s	remaining: 4.67s
# 650:	learn: 0.7587503	total: 8.68s	remaining: 4.65s
# 651:	learn: 0.7580442	total: 8.7s	remaining: 4.64s
# 652:	learn: 0.7577265	total: 8.71s	remaining: 4.63s
# 653:	learn: 0.7571308	total: 8.72s	remaining: 4.61s
# 654:	learn: 0.7565647	total: 8.73s	remaining: 4.6s
# 655:	learn: 0.7559325	total: 8.75s	remaining: 4.59s
# 656:	learn: 0.7553191	total: 8.76s	remaining: 4.57s
# 657:	learn: 0.7547438	total: 8.77s	remaining: 4.56s
# 658:	learn: 0.7539523	total: 8.79s	remaining: 4.55s
# 659:	learn: 0.7533589	total: 8.8s	remaining: 4.53s
# 660:	learn: 0.7530255	total: 8.81s	remaining: 4.52s
# 661:	learn: 0.7523412	total: 8.83s	remaining: 4.51s
# 662:	learn: 0.7516945	total: 8.84s	remaining: 4.49s
# 663:	learn: 0.7507523	total: 8.85s	remaining: 4.48s
# 664:	learn: 0.7500941	total: 8.87s	remaining: 4.47s
# 665:	learn: 0.7493008	total: 8.88s	remaining: 4.45s
# 666:	learn: 0.7489108	total: 8.89s	remaining: 4.44s
# 667:	learn: 0.7482406	total: 8.91s	remaining: 4.43s
# 668:	learn: 0.7476238	total: 8.92s	remaining: 4.41s
# 669:	learn: 0.7470309	total: 8.93s	remaining: 4.4s
# 670:	learn: 0.7463666	total: 8.95s	remaining: 4.39s
# 671:	learn: 0.7456289	total: 8.96s	remaining: 4.37s
# 672:	learn: 0.7451409	total: 8.97s	remaining: 4.36s
# 673:	learn: 0.7446590	total: 8.99s	remaining: 4.35s
# 674:	learn: 0.7440317	total: 9s	remaining: 4.33s
# 675:	learn: 0.7435288	total: 9.01s	remaining: 4.32s
# 676:	learn: 0.7426120	total: 9.03s	remaining: 4.31s
# 677:	learn: 0.7421276	total: 9.04s	remaining: 4.29s
# 678:	learn: 0.7416066	total: 9.05s	remaining: 4.28s
# 679:	learn: 0.7410333	total: 9.06s	remaining: 4.27s
# 680:	learn: 0.7401343	total: 9.08s	remaining: 4.25s
# 681:	learn: 0.7396375	total: 9.09s	remaining: 4.24s
# 682:	learn: 0.7392282	total: 9.11s	remaining: 4.23s
# 683:	learn: 0.7386303	total: 9.12s	remaining: 4.21s
# 684:	learn: 0.7381243	total: 9.13s	remaining: 4.2s
# 685:	learn: 0.7375141	total: 9.14s	remaining: 4.19s
# 686:	learn: 0.7369302	total: 9.16s	remaining: 4.17s
# 687:	learn: 0.7361702	total: 9.17s	remaining: 4.16s
# 688:	learn: 0.7355645	total: 9.18s	remaining: 4.14s
# 689:	learn: 0.7349962	total: 9.2s	remaining: 4.13s
# 690:	learn: 0.7346430	total: 9.21s	remaining: 4.12s
# 691:	learn: 0.7340766	total: 9.22s	remaining: 4.11s
# 692:	learn: 0.7332766	total: 9.24s	remaining: 4.09s
# 693:	learn: 0.7324706	total: 9.25s	remaining: 4.08s
# 694:	learn: 0.7316565	total: 9.27s	remaining: 4.07s
# 695:	learn: 0.7307980	total: 9.28s	remaining: 4.05s
# 696:	learn: 0.7302681	total: 9.3s	remaining: 4.04s
# 697:	learn: 0.7297804	total: 9.32s	remaining: 4.03s
# 698:	learn: 0.7293079	total: 9.34s	remaining: 4.02s
# 699:	learn: 0.7286652	total: 9.35s	remaining: 4.01s
# 700:	learn: 0.7281546	total: 9.37s	remaining: 4s
# 701:	learn: 0.7277411	total: 9.38s	remaining: 3.98s
# 702:	learn: 0.7268055	total: 9.4s	remaining: 3.97s
# 703:	learn: 0.7262701	total: 9.41s	remaining: 3.96s
# 704:	learn: 0.7257762	total: 9.42s	remaining: 3.94s
# 705:	learn: 0.7251193	total: 9.44s	remaining: 3.93s
# 706:	learn: 0.7246236	total: 9.45s	remaining: 3.92s
# 707:	learn: 0.7242615	total: 9.46s	remaining: 3.9s
# 708:	learn: 0.7235663	total: 9.48s	remaining: 3.89s
# 709:	learn: 0.7227395	total: 9.49s	remaining: 3.88s
# 710:	learn: 0.7219656	total: 9.5s	remaining: 3.86s
# 711:	learn: 0.7214946	total: 9.52s	remaining: 3.85s
# 712:	learn: 0.7211519	total: 9.53s	remaining: 3.84s
# 713:	learn: 0.7207021	total: 9.55s	remaining: 3.82s
# 714:	learn: 0.7202931	total: 9.56s	remaining: 3.81s
# 715:	learn: 0.7196360	total: 9.57s	remaining: 3.8s
# 716:	learn: 0.7191017	total: 9.59s	remaining: 3.78s
# 717:	learn: 0.7187601	total: 9.6s	remaining: 3.77s
# 718:	learn: 0.7184971	total: 9.61s	remaining: 3.76s
# 719:	learn: 0.7180178	total: 9.63s	remaining: 3.74s
# 720:	learn: 0.7175931	total: 9.64s	remaining: 3.73s
# 721:	learn: 0.7171654	total: 9.65s	remaining: 3.72s
# 722:	learn: 0.7163781	total: 9.67s	remaining: 3.7s
# 723:	learn: 0.7157169	total: 9.68s	remaining: 3.69s
# 724:	learn: 0.7153263	total: 9.69s	remaining: 3.68s
# 725:	learn: 0.7147033	total: 9.71s	remaining: 3.66s
# 726:	learn: 0.7142494	total: 9.72s	remaining: 3.65s
# 727:	learn: 0.7135343	total: 9.73s	remaining: 3.64s
# 728:	learn: 0.7129079	total: 9.75s	remaining: 3.62s
# 729:	learn: 0.7123784	total: 9.76s	remaining: 3.61s
# 730:	learn: 0.7117732	total: 9.77s	remaining: 3.6s
# 731:	learn: 0.7110782	total: 9.79s	remaining: 3.58s
# 732:	learn: 0.7107713	total: 9.8s	remaining: 3.57s
# 733:	learn: 0.7104616	total: 9.81s	remaining: 3.56s
# 734:	learn: 0.7098944	total: 9.83s	remaining: 3.54s
# 735:	learn: 0.7093828	total: 9.84s	remaining: 3.53s
# 736:	learn: 0.7087560	total: 9.86s	remaining: 3.52s
# 737:	learn: 0.7082833	total: 9.87s	remaining: 3.5s
# 738:	learn: 0.7077600	total: 9.88s	remaining: 3.49s
# 739:	learn: 0.7072800	total: 9.9s	remaining: 3.48s
# 740:	learn: 0.7067299	total: 9.91s	remaining: 3.46s
# 741:	learn: 0.7061782	total: 9.92s	remaining: 3.45s
# 742:	learn: 0.7056357	total: 9.94s	remaining: 3.44s
# 743:	learn: 0.7052141	total: 9.95s	remaining: 3.42s
# 744:	learn: 0.7047160	total: 9.96s	remaining: 3.41s
# 745:	learn: 0.7044463	total: 9.98s	remaining: 3.4s
# 746:	learn: 0.7035986	total: 9.99s	remaining: 3.38s
# 747:	learn: 0.7032098	total: 10s	remaining: 3.37s
# 748:	learn: 0.7025784	total: 10s	remaining: 3.36s
# 749:	learn: 0.7022333	total: 10s	remaining: 3.34s
# 750:	learn: 0.7020292	total: 10s	remaining: 3.33s
# 751:	learn: 0.7012448	total: 10.1s	remaining: 3.32s
# 752:	learn: 0.7007345	total: 10.1s	remaining: 3.3s
# 753:	learn: 0.7002447	total: 10.1s	remaining: 3.29s
# 754:	learn: 0.6997001	total: 10.1s	remaining: 3.28s
# 755:	learn: 0.6992317	total: 10.1s	remaining: 3.26s
# 756:	learn: 0.6987524	total: 10.1s	remaining: 3.25s
# 757:	learn: 0.6982828	total: 10.1s	remaining: 3.24s
# 758:	learn: 0.6977098	total: 10.2s	remaining: 3.22s
# 759:	learn: 0.6973979	total: 10.2s	remaining: 3.21s
# 760:	learn: 0.6968244	total: 10.2s	remaining: 3.2s
# 761:	learn: 0.6962102	total: 10.2s	remaining: 3.18s
# 762:	learn: 0.6957514	total: 10.2s	remaining: 3.17s
# 763:	learn: 0.6949244	total: 10.2s	remaining: 3.16s
# 764:	learn: 0.6948273	total: 10.2s	remaining: 3.14s
# 765:	learn: 0.6944750	total: 10.2s	remaining: 3.13s
# 766:	learn: 0.6941372	total: 10.3s	remaining: 3.12s
# 767:	learn: 0.6935252	total: 10.3s	remaining: 3.1s
# 768:	learn: 0.6929991	total: 10.3s	remaining: 3.09s
# 769:	learn: 0.6925708	total: 10.3s	remaining: 3.08s
# 770:	learn: 0.6919128	total: 10.3s	remaining: 3.06s
# 771:	learn: 0.6914871	total: 10.3s	remaining: 3.05s
# 772:	learn: 0.6910493	total: 10.3s	remaining: 3.04s
# 773:	learn: 0.6905974	total: 10.3s	remaining: 3.02s
# 774:	learn: 0.6900931	total: 10.4s	remaining: 3.01s
# 775:	learn: 0.6895288	total: 10.4s	remaining: 3s
# 776:	learn: 0.6888658	total: 10.4s	remaining: 2.98s
# 777:	learn: 0.6882631	total: 10.4s	remaining: 2.97s
# 778:	learn: 0.6878941	total: 10.4s	remaining: 2.96s
# 779:	learn: 0.6874570	total: 10.4s	remaining: 2.94s
# 780:	learn: 0.6871202	total: 10.4s	remaining: 2.93s
# 781:	learn: 0.6868241	total: 10.5s	remaining: 2.92s
# 782:	learn: 0.6862826	total: 10.5s	remaining: 2.9s
# 783:	learn: 0.6858633	total: 10.5s	remaining: 2.89s
# 784:	learn: 0.6853492	total: 10.5s	remaining: 2.88s
# 785:	learn: 0.6849981	total: 10.5s	remaining: 2.86s
# 786:	learn: 0.6843738	total: 10.5s	remaining: 2.85s
# 787:	learn: 0.6835827	total: 10.5s	remaining: 2.83s
# 788:	learn: 0.6831588	total: 10.6s	remaining: 2.82s
# 789:	learn: 0.6824952	total: 10.6s	remaining: 2.81s
# 790:	learn: 0.6818294	total: 10.6s	remaining: 2.79s
# 791:	learn: 0.6809438	total: 10.6s	remaining: 2.78s
# 792:	learn: 0.6801047	total: 10.6s	remaining: 2.77s
# 793:	learn: 0.6791776	total: 10.6s	remaining: 2.75s
# 794:	learn: 0.6786499	total: 10.6s	remaining: 2.74s
# 795:	learn: 0.6779956	total: 10.7s	remaining: 2.73s
# 796:	learn: 0.6774322	total: 10.7s	remaining: 2.72s
# 797:	learn: 0.6768629	total: 10.7s	remaining: 2.7s
# 798:	learn: 0.6758974	total: 10.7s	remaining: 2.69s
# 799:	learn: 0.6751431	total: 10.7s	remaining: 2.68s
# 800:	learn: 0.6748909	total: 10.7s	remaining: 2.66s
# 801:	learn: 0.6741501	total: 10.7s	remaining: 2.65s
# 802:	learn: 0.6737257	total: 10.7s	remaining: 2.64s
# 803:	learn: 0.6733835	total: 10.8s	remaining: 2.62s
# 804:	learn: 0.6730973	total: 10.8s	remaining: 2.61s
# 805:	learn: 0.6728384	total: 10.8s	remaining: 2.6s
# 806:	learn: 0.6723298	total: 10.8s	remaining: 2.58s
# 807:	learn: 0.6715675	total: 10.8s	remaining: 2.57s
# 808:	learn: 0.6711542	total: 10.8s	remaining: 2.56s
# 809:	learn: 0.6706471	total: 10.8s	remaining: 2.54s
# 810:	learn: 0.6703969	total: 10.9s	remaining: 2.53s
# 811:	learn: 0.6698239	total: 10.9s	remaining: 2.52s
# 812:	learn: 0.6688262	total: 10.9s	remaining: 2.5s
# 813:	learn: 0.6682589	total: 10.9s	remaining: 2.49s
# 814:	learn: 0.6675704	total: 10.9s	remaining: 2.48s
# 815:	learn: 0.6669864	total: 10.9s	remaining: 2.46s
# 816:	learn: 0.6665291	total: 10.9s	remaining: 2.45s
# 817:	learn: 0.6661433	total: 10.9s	remaining: 2.44s
# 818:	learn: 0.6656671	total: 11s	remaining: 2.42s
# 819:	learn: 0.6650210	total: 11s	remaining: 2.41s
# 820:	learn: 0.6647033	total: 11s	remaining: 2.4s
# 821:	learn: 0.6642889	total: 11s	remaining: 2.38s
# 822:	learn: 0.6636729	total: 11s	remaining: 2.37s
# 823:	learn: 0.6630034	total: 11s	remaining: 2.35s
# 824:	learn: 0.6623120	total: 11s	remaining: 2.34s
# 825:	learn: 0.6616993	total: 11.1s	remaining: 2.33s
# 826:	learn: 0.6613849	total: 11.1s	remaining: 2.31s
# 827:	learn: 0.6610541	total: 11.1s	remaining: 2.3s
# 828:	learn: 0.6603752	total: 11.1s	remaining: 2.29s
# 829:	learn: 0.6599526	total: 11.1s	remaining: 2.27s
# 830:	learn: 0.6595873	total: 11.1s	remaining: 2.26s
# 831:	learn: 0.6591318	total: 11.1s	remaining: 2.25s
# 832:	learn: 0.6586943	total: 11.1s	remaining: 2.23s
# 833:	learn: 0.6580660	total: 11.2s	remaining: 2.22s
# 834:	learn: 0.6574020	total: 11.2s	remaining: 2.21s
# 835:	learn: 0.6569655	total: 11.2s	remaining: 2.19s
# 836:	learn: 0.6565808	total: 11.2s	remaining: 2.18s
# 837:	learn: 0.6559647	total: 11.2s	remaining: 2.17s
# 838:	learn: 0.6552593	total: 11.2s	remaining: 2.15s
# 839:	learn: 0.6546512	total: 11.2s	remaining: 2.14s
# 840:	learn: 0.6542772	total: 11.2s	remaining: 2.13s
# 841:	learn: 0.6537506	total: 11.3s	remaining: 2.11s
# 842:	learn: 0.6533558	total: 11.3s	remaining: 2.1s
# 843:	learn: 0.6527562	total: 11.3s	remaining: 2.09s
# 844:	learn: 0.6520730	total: 11.3s	remaining: 2.07s
# 845:	learn: 0.6517477	total: 11.3s	remaining: 2.06s
# 846:	learn: 0.6514788	total: 11.3s	remaining: 2.05s
# 847:	learn: 0.6509041	total: 11.3s	remaining: 2.03s
# 848:	learn: 0.6502887	total: 11.4s	remaining: 2.02s
# 849:	learn: 0.6497896	total: 11.4s	remaining: 2.01s
# 850:	learn: 0.6491873	total: 11.4s	remaining: 1.99s
# 851:	learn: 0.6487387	total: 11.4s	remaining: 1.98s
# 852:	learn: 0.6478759	total: 11.4s	remaining: 1.97s
# 853:	learn: 0.6472135	total: 11.4s	remaining: 1.95s
# 854:	learn: 0.6466268	total: 11.4s	remaining: 1.94s
# 855:	learn: 0.6463282	total: 11.4s	remaining: 1.93s
# 856:	learn: 0.6456383	total: 11.5s	remaining: 1.91s
# 857:	learn: 0.6451920	total: 11.5s	remaining: 1.9s
# 858:	learn: 0.6447745	total: 11.5s	remaining: 1.89s
# 859:	learn: 0.6442977	total: 11.5s	remaining: 1.87s
# 860:	learn: 0.6437513	total: 11.5s	remaining: 1.86s
# 861:	learn: 0.6430670	total: 11.5s	remaining: 1.85s
# 862:	learn: 0.6427446	total: 11.5s	remaining: 1.83s
# 863:	learn: 0.6425172	total: 11.6s	remaining: 1.82s
# 864:	learn: 0.6418673	total: 11.6s	remaining: 1.81s
# 865:	learn: 0.6415667	total: 11.6s	remaining: 1.79s
# 866:	learn: 0.6410017	total: 11.6s	remaining: 1.78s
# 867:	learn: 0.6403658	total: 11.6s	remaining: 1.77s
# 868:	learn: 0.6398260	total: 11.6s	remaining: 1.75s
# 869:	learn: 0.6392852	total: 11.6s	remaining: 1.74s
# 870:	learn: 0.6383452	total: 11.7s	remaining: 1.73s
# 871:	learn: 0.6374666	total: 11.7s	remaining: 1.71s
# 872:	learn: 0.6367556	total: 11.7s	remaining: 1.7s
# 873:	learn: 0.6363441	total: 11.7s	remaining: 1.69s
# 874:	learn: 0.6358115	total: 11.7s	remaining: 1.67s
# 875:	learn: 0.6351420	total: 11.7s	remaining: 1.66s
# 876:	learn: 0.6348499	total: 11.7s	remaining: 1.65s
# 877:	learn: 0.6343029	total: 11.8s	remaining: 1.63s
# 878:	learn: 0.6337944	total: 11.8s	remaining: 1.62s
# 879:	learn: 0.6331150	total: 11.8s	remaining: 1.61s
# 880:	learn: 0.6322097	total: 11.8s	remaining: 1.59s
# 881:	learn: 0.6318170	total: 11.8s	remaining: 1.58s
# 882:	learn: 0.6311345	total: 11.8s	remaining: 1.57s
# 883:	learn: 0.6306781	total: 11.8s	remaining: 1.55s
# 884:	learn: 0.6299856	total: 11.9s	remaining: 1.54s
# 885:	learn: 0.6294755	total: 11.9s	remaining: 1.53s
# 886:	learn: 0.6290216	total: 11.9s	remaining: 1.51s
# 887:	learn: 0.6286342	total: 11.9s	remaining: 1.5s
# 888:	learn: 0.6279657	total: 11.9s	remaining: 1.49s
# 889:	learn: 0.6277037	total: 11.9s	remaining: 1.47s
# 890:	learn: 0.6273928	total: 11.9s	remaining: 1.46s
# 891:	learn: 0.6267168	total: 11.9s	remaining: 1.45s
# 892:	learn: 0.6262456	total: 12s	remaining: 1.43s
# 893:	learn: 0.6259221	total: 12s	remaining: 1.42s
# 894:	learn: 0.6256888	total: 12s	remaining: 1.41s
# 895:	learn: 0.6248674	total: 12s	remaining: 1.39s
# 896:	learn: 0.6245061	total: 12s	remaining: 1.38s
# 897:	learn: 0.6242990	total: 12s	remaining: 1.37s
# 898:	learn: 0.6235445	total: 12s	remaining: 1.35s
# 899:	learn: 0.6231890	total: 12.1s	remaining: 1.34s
# 900:	learn: 0.6228930	total: 12.1s	remaining: 1.33s
# 901:	learn: 0.6225500	total: 12.1s	remaining: 1.31s
# 902:	learn: 0.6220363	total: 12.1s	remaining: 1.3s
# 903:	learn: 0.6216665	total: 12.1s	remaining: 1.28s
# 904:	learn: 0.6213259	total: 12.1s	remaining: 1.27s
# 905:	learn: 0.6208753	total: 12.1s	remaining: 1.26s
# 906:	learn: 0.6202889	total: 12.2s	remaining: 1.25s
# 907:	learn: 0.6199228	total: 12.2s	remaining: 1.23s
# 908:	learn: 0.6190349	total: 12.2s	remaining: 1.22s
# 909:	learn: 0.6185062	total: 12.2s	remaining: 1.21s
# 910:	learn: 0.6176866	total: 12.2s	remaining: 1.19s
# 911:	learn: 0.6174293	total: 12.2s	remaining: 1.18s
# 912:	learn: 0.6167882	total: 12.2s	remaining: 1.17s
# 913:	learn: 0.6160961	total: 12.2s	remaining: 1.15s
# 914:	learn: 0.6154922	total: 12.3s	remaining: 1.14s
# 915:	learn: 0.6152808	total: 12.3s	remaining: 1.13s
# 916:	learn: 0.6147656	total: 12.3s	remaining: 1.11s
# 917:	learn: 0.6141785	total: 12.3s	remaining: 1.1s
# 918:	learn: 0.6137377	total: 12.3s	remaining: 1.08s
# 919:	learn: 0.6130751	total: 12.3s	remaining: 1.07s
# 920:	learn: 0.6125554	total: 12.3s	remaining: 1.06s
# 921:	learn: 0.6121355	total: 12.4s	remaining: 1.04s
# 922:	learn: 0.6115220	total: 12.4s	remaining: 1.03s
# 923:	learn: 0.6108111	total: 12.4s	remaining: 1.02s
# 924:	learn: 0.6100877	total: 12.4s	remaining: 1s
# 925:	learn: 0.6096884	total: 12.4s	remaining: 992ms
# 926:	learn: 0.6093123	total: 12.4s	remaining: 979ms
# 927:	learn: 0.6091309	total: 12.4s	remaining: 965ms
# 928:	learn: 0.6086109	total: 12.5s	remaining: 952ms
# ...
# 696:	learn: 0.5401717	total: 8.43s	remaining: 3.67s
# 697:	learn: 0.5396082	total: 8.44s	remaining: 3.65s
# 698:	learn: 0.5389323	total: 8.46s	remaining: 3.64s
# 699:	learn: 0.5382698	total: 8.47s	remaining: 3.63s
# 700:	learn: 0.5379389	total: 8.48s	remaining: 3.62s
# 701:	learn: 0.5375115	total: 8.49s	remaining: 3.6s
# 702:	learn: 0.5368144	total: 8.5s	remaining: 3.59s
# 703:	learn: 0.5364069	total: 8.52s	remaining: 3.58s
# 704:	learn: 0.5361165	total: 8.53s	remaining: 3.57s
# 705:	learn: 0.5351043	total: 8.54s	remaining: 3.56s
# 706:	learn: 0.5343349	total: 8.55s	remaining: 3.54s
# 707:	learn: 0.5333333	total: 8.56s	remaining: 3.53s
# 708:	learn: 0.5326284	total: 8.57s	remaining: 3.52s
# 709:	learn: 0.5318536	total: 8.58s	remaining: 3.5s
# 710:	learn: 0.5311869	total: 8.59s	remaining: 3.49s
# 711:	learn: 0.5307021	total: 8.61s	remaining: 3.48s
# 712:	learn: 0.5301046	total: 8.63s	remaining: 3.47s
# 713:	learn: 0.5296107	total: 8.64s	remaining: 3.46s
# 714:	learn: 0.5288558	total: 8.65s	remaining: 3.45s
# 715:	learn: 0.5283285	total: 8.67s	remaining: 3.44s
# 716:	learn: 0.5279014	total: 8.68s	remaining: 3.42s
# 717:	learn: 0.5275024	total: 8.69s	remaining: 3.41s
# 718:	learn: 0.5270471	total: 8.7s	remaining: 3.4s
# 719:	learn: 0.5263628	total: 8.71s	remaining: 3.39s
# 720:	learn: 0.5257205	total: 8.72s	remaining: 3.38s
# 721:	learn: 0.5255051	total: 8.73s	remaining: 3.36s
# 722:	learn: 0.5244433	total: 8.75s	remaining: 3.35s
# 723:	learn: 0.5238558	total: 8.76s	remaining: 3.34s
# 724:	learn: 0.5234807	total: 8.77s	remaining: 3.33s
# 725:	learn: 0.5226228	total: 8.78s	remaining: 3.31s
# 726:	learn: 0.5222717	total: 8.79s	remaining: 3.3s
# 727:	learn: 0.5216906	total: 8.8s	remaining: 3.29s
# 728:	learn: 0.5211347	total: 8.81s	remaining: 3.28s
# 729:	learn: 0.5205296	total: 8.83s	remaining: 3.26s
# 730:	learn: 0.5200512	total: 8.84s	remaining: 3.25s
# 731:	learn: 0.5196394	total: 8.85s	remaining: 3.24s
# 732:	learn: 0.5190918	total: 8.86s	remaining: 3.23s
# 733:	learn: 0.5187282	total: 8.87s	remaining: 3.21s
# 734:	learn: 0.5182193	total: 8.88s	remaining: 3.2s
# 735:	learn: 0.5174391	total: 8.9s	remaining: 3.19s
# 736:	learn: 0.5163132	total: 8.91s	remaining: 3.18s
# 737:	learn: 0.5158519	total: 8.92s	remaining: 3.17s
# 738:	learn: 0.5155508	total: 8.93s	remaining: 3.15s
# 739:	learn: 0.5145638	total: 8.94s	remaining: 3.14s
# 740:	learn: 0.5141387	total: 8.95s	remaining: 3.13s
# 741:	learn: 0.5134763	total: 8.97s	remaining: 3.12s
# 742:	learn: 0.5128024	total: 8.98s	remaining: 3.1s
# 743:	learn: 0.5121361	total: 8.99s	remaining: 3.09s
# 744:	learn: 0.5116376	total: 9s	remaining: 3.08s
# 745:	learn: 0.5108854	total: 9.01s	remaining: 3.07s
# 746:	learn: 0.5103633	total: 9.02s	remaining: 3.06s
# 747:	learn: 0.5097213	total: 9.04s	remaining: 3.04s
# 748:	learn: 0.5087614	total: 9.05s	remaining: 3.03s
# 749:	learn: 0.5079624	total: 9.06s	remaining: 3.02s
# 750:	learn: 0.5073741	total: 9.07s	remaining: 3.01s
# 751:	learn: 0.5068225	total: 9.08s	remaining: 2.99s
# 752:	learn: 0.5064591	total: 9.09s	remaining: 2.98s
# 753:	learn: 0.5057629	total: 9.1s	remaining: 2.97s
# 754:	learn: 0.5049097	total: 9.12s	remaining: 2.96s
# 755:	learn: 0.5043967	total: 9.13s	remaining: 2.94s
# 756:	learn: 0.5040644	total: 9.14s	remaining: 2.93s
# 757:	learn: 0.5033633	total: 9.15s	remaining: 2.92s
# 758:	learn: 0.5026794	total: 9.16s	remaining: 2.91s
# 759:	learn: 0.5018584	total: 9.17s	remaining: 2.9s
# 760:	learn: 0.5014041	total: 9.18s	remaining: 2.88s
# 761:	learn: 0.5002768	total: 9.19s	remaining: 2.87s
# 762:	learn: 0.4996570	total: 9.21s	remaining: 2.86s
# 763:	learn: 0.4990377	total: 9.22s	remaining: 2.85s
# 764:	learn: 0.4984007	total: 9.23s	remaining: 2.83s
# 765:	learn: 0.4975381	total: 9.24s	remaining: 2.82s
# 766:	learn: 0.4966254	total: 9.25s	remaining: 2.81s
# 767:	learn: 0.4961742	total: 9.27s	remaining: 2.8s
# 768:	learn: 0.4954106	total: 9.28s	remaining: 2.79s
# 769:	learn: 0.4946251	total: 9.3s	remaining: 2.78s
# 770:	learn: 0.4942448	total: 9.31s	remaining: 2.77s
# 771:	learn: 0.4936932	total: 9.32s	remaining: 2.75s
# 772:	learn: 0.4930342	total: 9.33s	remaining: 2.74s
# 773:	learn: 0.4925552	total: 9.35s	remaining: 2.73s
# 774:	learn: 0.4918843	total: 9.36s	remaining: 2.72s
# 775:	learn: 0.4912080	total: 9.37s	remaining: 2.7s
# 776:	learn: 0.4903802	total: 9.38s	remaining: 2.69s
# 777:	learn: 0.4897817	total: 9.39s	remaining: 2.68s
# 778:	learn: 0.4888772	total: 9.4s	remaining: 2.67s
# 779:	learn: 0.4877995	total: 9.42s	remaining: 2.66s
# 780:	learn: 0.4872202	total: 9.43s	remaining: 2.64s
# 781:	learn: 0.4865653	total: 9.44s	remaining: 2.63s
# 782:	learn: 0.4857786	total: 9.45s	remaining: 2.62s
# 783:	learn: 0.4850468	total: 9.47s	remaining: 2.61s
# 784:	learn: 0.4845127	total: 9.48s	remaining: 2.6s
# 785:	learn: 0.4837764	total: 9.49s	remaining: 2.58s
# 786:	learn: 0.4833532	total: 9.51s	remaining: 2.57s
# 787:	learn: 0.4825404	total: 9.52s	remaining: 2.56s
# 788:	learn: 0.4819823	total: 9.53s	remaining: 2.55s
# 789:	learn: 0.4817207	total: 9.54s	remaining: 2.54s
# 790:	learn: 0.4813681	total: 9.56s	remaining: 2.52s
# 791:	learn: 0.4806339	total: 9.57s	remaining: 2.51s
# 792:	learn: 0.4798509	total: 9.58s	remaining: 2.5s
# 793:	learn: 0.4791680	total: 9.6s	remaining: 2.49s
# 794:	learn: 0.4787365	total: 9.61s	remaining: 2.48s
# 795:	learn: 0.4780259	total: 9.62s	remaining: 2.46s
# 796:	learn: 0.4775934	total: 9.63s	remaining: 2.45s
# 797:	learn: 0.4767377	total: 9.64s	remaining: 2.44s
# 798:	learn: 0.4759929	total: 9.65s	remaining: 2.43s
# 799:	learn: 0.4754589	total: 9.67s	remaining: 2.42s
# 800:	learn: 0.4748455	total: 9.68s	remaining: 2.4s
# 801:	learn: 0.4746145	total: 9.69s	remaining: 2.39s
# 802:	learn: 0.4739061	total: 9.7s	remaining: 2.38s
# 803:	learn: 0.4731922	total: 9.71s	remaining: 2.37s
# 804:	learn: 0.4725433	total: 9.73s	remaining: 2.36s
# 805:	learn: 0.4716833	total: 9.74s	remaining: 2.34s
# 806:	learn: 0.4713146	total: 9.75s	remaining: 2.33s
# 807:	learn: 0.4708775	total: 9.76s	remaining: 2.32s
# 808:	learn: 0.4703121	total: 9.77s	remaining: 2.31s
# 809:	learn: 0.4699541	total: 9.78s	remaining: 2.29s
# 810:	learn: 0.4696482	total: 9.8s	remaining: 2.28s
# 811:	learn: 0.4688456	total: 9.81s	remaining: 2.27s
# 812:	learn: 0.4683360	total: 9.82s	remaining: 2.26s
# 813:	learn: 0.4678598	total: 9.83s	remaining: 2.25s
# 814:	learn: 0.4672522	total: 9.84s	remaining: 2.23s
# 815:	learn: 0.4667237	total: 9.85s	remaining: 2.22s
# 816:	learn: 0.4664187	total: 9.87s	remaining: 2.21s
# 817:	learn: 0.4660141	total: 9.88s	remaining: 2.2s
# 818:	learn: 0.4654283	total: 9.89s	remaining: 2.19s
# 819:	learn: 0.4645305	total: 9.91s	remaining: 2.17s
# 820:	learn: 0.4641700	total: 9.92s	remaining: 2.16s
# 821:	learn: 0.4638751	total: 9.93s	remaining: 2.15s
# 822:	learn: 0.4635532	total: 9.94s	remaining: 2.14s
# 823:	learn: 0.4631234	total: 9.96s	remaining: 2.13s
# 824:	learn: 0.4627228	total: 9.97s	remaining: 2.11s
# 825:	learn: 0.4622990	total: 9.98s	remaining: 2.1s
# 826:	learn: 0.4613548	total: 9.99s	remaining: 2.09s
# 827:	learn: 0.4606379	total: 10s	remaining: 2.08s
# 828:	learn: 0.4602467	total: 10s	remaining: 2.07s
# 829:	learn: 0.4596708	total: 10s	remaining: 2.05s
# 830:	learn: 0.4590717	total: 10s	remaining: 2.04s
# 831:	learn: 0.4585941	total: 10.1s	remaining: 2.03s
# 832:	learn: 0.4579390	total: 10.1s	remaining: 2.02s
# 833:	learn: 0.4574244	total: 10.1s	remaining: 2.01s
# 834:	learn: 0.4572050	total: 10.1s	remaining: 1.99s
# 835:	learn: 0.4568183	total: 10.1s	remaining: 1.98s
# 836:	learn: 0.4562484	total: 10.1s	remaining: 1.97s
# 837:	learn: 0.4558543	total: 10.1s	remaining: 1.96s
# 838:	learn: 0.4552202	total: 10.1s	remaining: 1.95s
# 839:	learn: 0.4545257	total: 10.2s	remaining: 1.94s
# 840:	learn: 0.4542050	total: 10.2s	remaining: 1.92s
# 841:	learn: 0.4535155	total: 10.2s	remaining: 1.91s
# 842:	learn: 0.4531946	total: 10.2s	remaining: 1.9s
# 843:	learn: 0.4525797	total: 10.2s	remaining: 1.89s
# 844:	learn: 0.4517760	total: 10.2s	remaining: 1.88s
# 845:	learn: 0.4514724	total: 10.2s	remaining: 1.86s
# 846:	learn: 0.4506909	total: 10.3s	remaining: 1.85s
# 847:	learn: 0.4502339	total: 10.3s	remaining: 1.84s
# 848:	learn: 0.4495630	total: 10.3s	remaining: 1.83s
# 849:	learn: 0.4489466	total: 10.3s	remaining: 1.82s
# 850:	learn: 0.4482850	total: 10.3s	remaining: 1.8s
# 851:	learn: 0.4478776	total: 10.3s	remaining: 1.79s
# 852:	learn: 0.4474621	total: 10.3s	remaining: 1.78s
# 853:	learn: 0.4470013	total: 10.3s	remaining: 1.77s
# 854:	learn: 0.4462502	total: 10.4s	remaining: 1.76s
# 855:	learn: 0.4458629	total: 10.4s	remaining: 1.75s
# 856:	learn: 0.4453445	total: 10.4s	remaining: 1.73s
# 857:	learn: 0.4450487	total: 10.4s	remaining: 1.72s
# 858:	learn: 0.4446842	total: 10.4s	remaining: 1.71s
# 859:	learn: 0.4441505	total: 10.4s	remaining: 1.7s
# 860:	learn: 0.4430872	total: 10.4s	remaining: 1.68s
# 861:	learn: 0.4426721	total: 10.4s	remaining: 1.67s
# 862:	learn: 0.4421192	total: 10.5s	remaining: 1.66s
# 863:	learn: 0.4417477	total: 10.5s	remaining: 1.65s
# 864:	learn: 0.4411966	total: 10.5s	remaining: 1.64s
# 865:	learn: 0.4404433	total: 10.5s	remaining: 1.62s
# 866:	learn: 0.4398885	total: 10.5s	remaining: 1.61s
# 867:	learn: 0.4395433	total: 10.5s	remaining: 1.6s
# 868:	learn: 0.4391123	total: 10.5s	remaining: 1.59s
# 869:	learn: 0.4386914	total: 10.6s	remaining: 1.58s
# 870:	learn: 0.4383844	total: 10.6s	remaining: 1.56s
# 871:	learn: 0.4381035	total: 10.6s	remaining: 1.55s
# 872:	learn: 0.4372329	total: 10.6s	remaining: 1.54s
# 873:	learn: 0.4369233	total: 10.6s	remaining: 1.53s
# 874:	learn: 0.4361368	total: 10.6s	remaining: 1.52s
# 875:	learn: 0.4357432	total: 10.6s	remaining: 1.5s
# 876:	learn: 0.4352034	total: 10.6s	remaining: 1.49s
# 877:	learn: 0.4350231	total: 10.7s	remaining: 1.48s
# 878:	learn: 0.4346238	total: 10.7s	remaining: 1.47s
# 879:	learn: 0.4338334	total: 10.7s	remaining: 1.46s
# 880:	learn: 0.4331664	total: 10.7s	remaining: 1.44s
# 881:	learn: 0.4326508	total: 10.7s	remaining: 1.43s
# 882:	learn: 0.4321921	total: 10.7s	remaining: 1.42s
# 883:	learn: 0.4316435	total: 10.7s	remaining: 1.41s
# 884:	learn: 0.4312883	total: 10.7s	remaining: 1.4s
# 885:	learn: 0.4310620	total: 10.8s	remaining: 1.38s
# 886:	learn: 0.4306498	total: 10.8s	remaining: 1.37s
# 887:	learn: 0.4301830	total: 10.8s	remaining: 1.36s
# 888:	learn: 0.4298575	total: 10.8s	remaining: 1.35s
# 889:	learn: 0.4291954	total: 10.8s	remaining: 1.33s
# 890:	learn: 0.4289149	total: 10.8s	remaining: 1.32s
# 891:	learn: 0.4279410	total: 10.8s	remaining: 1.31s
# 892:	learn: 0.4274925	total: 10.8s	remaining: 1.3s
# 893:	learn: 0.4271792	total: 10.9s	remaining: 1.29s
# 894:	learn: 0.4270756	total: 10.9s	remaining: 1.27s
# 895:	learn: 0.4266426	total: 10.9s	remaining: 1.26s
# 896:	learn: 0.4263050	total: 10.9s	remaining: 1.25s
# 897:	learn: 0.4259808	total: 10.9s	remaining: 1.24s
# 898:	learn: 0.4254521	total: 10.9s	remaining: 1.23s
# 899:	learn: 0.4251528	total: 10.9s	remaining: 1.22s
# 900:	learn: 0.4247057	total: 10.9s	remaining: 1.2s
# 901:	learn: 0.4239919	total: 11s	remaining: 1.19s
# 902:	learn: 0.4234009	total: 11s	remaining: 1.18s
# 903:	learn: 0.4228236	total: 11s	remaining: 1.17s
# 904:	learn: 0.4224464	total: 11s	remaining: 1.15s
# 905:	learn: 0.4217040	total: 11s	remaining: 1.14s
# 906:	learn: 0.4211139	total: 11s	remaining: 1.13s
# 907:	learn: 0.4205895	total: 11s	remaining: 1.12s
# 908:	learn: 0.4199758	total: 11s	remaining: 1.1s
# 909:	learn: 0.4197249	total: 11.1s	remaining: 1.09s
# 910:	learn: 0.4190812	total: 11.1s	remaining: 1.08s
# 911:	learn: 0.4185595	total: 11.1s	remaining: 1.07s
# 912:	learn: 0.4178427	total: 11.1s	remaining: 1.06s
# 913:	learn: 0.4173353	total: 11.1s	remaining: 1.04s
# 914:	learn: 0.4166003	total: 11.1s	remaining: 1.03s
# 915:	learn: 0.4159530	total: 11.1s	remaining: 1.02s
# 916:	learn: 0.4154831	total: 11.1s	remaining: 1.01s
# 917:	learn: 0.4150301	total: 11.1s	remaining: 996ms
# 918:	learn: 0.4144681	total: 11.2s	remaining: 983ms
# 919:	learn: 0.4140146	total: 11.2s	remaining: 971ms
# 920:	learn: 0.4134505	total: 11.2s	remaining: 959ms
# 921:	learn: 0.4129816	total: 11.2s	remaining: 947ms
# 922:	learn: 0.4126330	total: 11.2s	remaining: 935ms
# 923:	learn: 0.4124155	total: 11.2s	remaining: 923ms
# 924:	learn: 0.4120063	total: 11.2s	remaining: 910ms
# 925:	learn: 0.4117091	total: 11.2s	remaining: 898ms
# 926:	learn: 0.4113378	total: 11.3s	remaining: 886ms
# 927:	learn: 0.4110040	total: 11.3s	remaining: 874ms
# 928:	learn: 0.4105885	total: 11.3s	remaining: 862ms
# 929:	learn: 0.4100405	total: 11.3s	remaining: 849ms
# 930:	learn: 0.4097426	total: 11.3s	remaining: 837ms
# 931:	learn: 0.4093832	total: 11.3s	remaining: 825ms
# 932:	learn: 0.4087009	total: 11.3s	remaining: 813ms
# 933:	learn: 0.4083380	total: 11.3s	remaining: 801ms
# 934:	learn: 0.4079128	total: 11.3s	remaining: 789ms
# 935:	learn: 0.4075913	total: 11.4s	remaining: 776ms
# 936:	learn: 0.4072671	total: 11.4s	remaining: 764ms
# 937:	learn: 0.4069735	total: 11.4s	remaining: 752ms
# 938:	learn: 0.4067437	total: 11.4s	remaining: 740ms
# 939:	learn: 0.4061118	total: 11.4s	remaining: 728ms
# 940:	learn: 0.4056318	total: 11.4s	remaining: 716ms
# 941:	learn: 0.4050366	total: 11.4s	remaining: 704ms
# 942:	learn: 0.4048159	total: 11.4s	remaining: 691ms
# 943:	learn: 0.4046323	total: 11.4s	remaining: 679ms
# 944:	learn: 0.4042341	total: 11.5s	remaining: 667ms
# 945:	learn: 0.4035588	total: 11.5s	remaining: 655ms
# 946:	learn: 0.4027864	total: 11.5s	remaining: 643ms
# 947:	learn: 0.4023496	total: 11.5s	remaining: 631ms
# 948:	learn: 0.4018677	total: 11.5s	remaining: 618ms
# 949:	learn: 0.4015305	total: 11.5s	remaining: 606ms
# 950:	learn: 0.4011763	total: 11.5s	remaining: 594ms
# 951:	learn: 0.4006043	total: 11.5s	remaining: 582ms
# 952:	learn: 0.4003738	total: 11.6s	remaining: 570ms
# 953:	learn: 0.3997002	total: 11.6s	remaining: 558ms
# 954:	learn: 0.3993662	total: 11.6s	remaining: 545ms
# 955:	learn: 0.3991594	total: 11.6s	remaining: 533ms
# 956:	learn: 0.3988297	total: 11.6s	remaining: 521ms
# 957:	learn: 0.3983094	total: 11.6s	remaining: 509ms
# 958:	learn: 0.3980254	total: 11.6s	remaining: 497ms
# 959:	learn: 0.3973930	total: 11.6s	remaining: 485ms
# 960:	learn: 0.3971041	total: 11.6s	remaining: 473ms
# 961:	learn: 0.3966565	total: 11.7s	remaining: 460ms
# 962:	learn: 0.3962618	total: 11.7s	remaining: 448ms
# 963:	learn: 0.3960332	total: 11.7s	remaining: 436ms
# 964:	learn: 0.3956423	total: 11.7s	remaining: 424ms
# 965:	learn: 0.3951652	total: 11.7s	remaining: 412ms
# 966:	learn: 0.3944883	total: 11.7s	remaining: 400ms
# 967:	learn: 0.3940923	total: 11.7s	remaining: 388ms
# 968:	learn: 0.3936612	total: 11.7s	remaining: 375ms
# 969:	learn: 0.3933795	total: 11.7s	remaining: 363ms
# 970:	learn: 0.3932055	total: 11.8s	remaining: 351ms
# 971:	learn: 0.3927968	total: 11.8s	remaining: 339ms
# 972:	learn: 0.3922496	total: 11.8s	remaining: 327ms
# 973:	learn: 0.3919658	total: 11.8s	remaining: 315ms
# 974:	learn: 0.3916195	total: 11.8s	remaining: 303ms
# 975:	learn: 0.3912353	total: 11.8s	remaining: 291ms
# 976:	learn: 0.3908171	total: 11.8s	remaining: 279ms
# 977:	learn: 0.3904521	total: 11.8s	remaining: 266ms
# 978:	learn: 0.3898820	total: 11.9s	remaining: 254ms
# 979:	learn: 0.3895835	total: 11.9s	remaining: 242ms
# 980:	learn: 0.3892223	total: 11.9s	remaining: 230ms
# 981:	learn: 0.3887435	total: 11.9s	remaining: 218ms
# 982:	learn: 0.3884444	total: 11.9s	remaining: 206ms
# 983:	learn: 0.3882076	total: 11.9s	remaining: 194ms
# 984:	learn: 0.3877158	total: 11.9s	remaining: 182ms
# 985:	learn: 0.3873617	total: 11.9s	remaining: 169ms
# 986:	learn: 0.3864693	total: 11.9s	remaining: 157ms
# 987:	learn: 0.3860053	total: 12s	remaining: 145ms
# 988:	learn: 0.3851676	total: 12s	remaining: 133ms
# 989:	learn: 0.3848093	total: 12s	remaining: 121ms
# 990:	learn: 0.3844295	total: 12s	remaining: 109ms
# 991:	learn: 0.3840108	total: 12s	remaining: 96.8ms
# 992:	learn: 0.3837004	total: 12s	remaining: 84.7ms
# 993:	learn: 0.3834941	total: 12s	remaining: 72.6ms
# 994:	learn: 0.3827696	total: 12s	remaining: 60.5ms
# 995:	learn: 0.3824898	total: 12s	remaining: 48.4ms
# 996:	learn: 0.3817562	total: 12.1s	remaining: 36.3ms
# 997:	learn: 0.3812648	total: 12.1s	remaining: 24.2ms
# 998:	learn: 0.3808477	total: 12.1s	remaining: 12.1ms
# 999:	learn: 0.3806111	total: 12.1s	remaining: 0us
# Model <catboost.core.CatBoostClassifier object at 0x0000015D2842BF70> CV_Score: [0.49314554 0.50601052 0.49276995 0.49924869 0.50197183 0.49229902]
# Model <catboost.core.CatBoostClassifier object at 0x0000015D2842BF70> Model Accuracy: 0.5084491175366128

# %% [markdown]
# F1 Score

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_test, preds, average="macro")
#y_train_knn_pred = cross_val_predict(knn_clf, X_train, y_train, cv=3)
#f1_score(y_train, y_train_knn_pred, average="macro")
# Out:
# 0.26184566567907136

# %% [markdown]
# Using VotingClassifier to improve results

# %%
from sklearn.ensemble import VotingClassifier

# voting classifier
final_model = VotingClassifier(
    estimators=[("rf", rfc), ("xgb", xgb_clf),("log_reg",log_reg) ],)

# training
final_model.fit(transformed_columns, y_train)

# prediction
prediction = final_model.predict(transformed_columns_test)

# evaluation
accuracy = round(accuracy_score(y_test, prediction) * 100, 3)

print(f" Accuracy: {accuracy}%")
# Out:
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  Accuracy: 52.604%

# %% [markdown]
# Using Bagging

# %%
from sklearn.ensemble import BaggingClassifier
# bagging
bag_clf = BaggingClassifier(XGBClassifier(random_state=42, learning_rate= 0.001, 
                                      max_depth= 6, min_child_weight= 3, n_estimators= 500))

# training
bag_clf.fit(transformed_columns, y_train)

# prediction
prediction = bag_clf.predict(transformed_columns_test)

# evaluation
accuracy = round(accuracy_score(y_test, prediction) * 100, 3)

print(f" Accuracy: {accuracy}%")

# %%
# from lazypredict.Supervised import LazyClassifier
# lacla = LazyClassifier(verbose=0,predictions=True)
# lacla.fit(x_train, x_test, y_train, y_test)

# %% [markdown]
# Using Stacking

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import GradientBoostingClassifier

# {'KNN': knn,'RFC':rfc , "log_reg": log_reg,"sgd_clf":sgd_clf,'xgb_clf':xgb_clf}

estimators = [('RFC',rfc), ("log_reg",log_reg), ('xgb_clf',xgb_clf),]
# {'KNN': knn,'RFC':rfc , "log_reg": log_reg,"sgd_clf":sgd_clf,'xgb_clf':xgb_clf}

# building the model
final_estimator = GradientBoostingClassifier(random_state=42)

# Stacking Classifier
stack_clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)

# training
stack_clf.fit(transformed_columns, y_train)

# prediction
prediction = stack_clf.predict(transformed_columns_test)

# evaluation
accuracy = round(accuracy_score(y_test, prediction) * 100, 3)

print(f" Accuracy: {accuracy}%")
# Out:
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#  Accuracy: 57.882%

# %% [markdown]
# Using PCA

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components=3)
# principal_components = pca.fit_transform(transformed_columns)
# principal_components
# pca.explained_variance_ratio_
# df_comp = pd.DataFrame(pca.components_,index=['PC1','PC2'],columns=x.columns)

# %% [markdown]
# # Working with the Test set
# Using the model with the highest score

# %% [markdown]
# Start by Importing the Test set

# %%
test_set =pd.read_csv('file-location')

print('test_set shape is',test_set.shape)
Id=test_set['Id']

# train_set.drop(['Id'], axis=1, inplace=True) 
# print(train_set.head())
# print("train_set shape is: ", train_set.shape)
# test_set.drop(cat_attribs,axis=1, inplace=True)
# Out:
# test_set shape is (3600, 17)

# %%
print("Column names: ", test_set.columns)
test_set.columns= test_set.columns.str.replace(" ","_").str.lower()
print("Column names after: ", test_set.columns)
# Out:
# Column names:  Index(['Id', 'Artist Name', 'Track Name', 'Popularity', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_in min/ms', 'time_signature'],
#       dtype='object')
# Column names after:  Index(['id', 'artist_name', 'track_name', 'popularity', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_in_min/ms', 'time_signature'],
#       dtype='object')

# %%
#We use a variable called condition to make the code below shorter
condition = test_set['duration_in_min/ms'] <=40

# If duration_in_min/ms value is less than 40, then multiply by 60,000

#This changes the data in 'duration_in_min/ms' column
test_set.loc[condition,'duration_in_min/ms'] = test_set.loc[condition,'duration_in_min/ms']*60000

#To check that are values were changed
# (test_set['duration_in_min/ms'] <=40).value_counts() 

test_set.rename(columns={"duration_in_min/ms": "duration_in_ms"},inplace=True)
test_set.columns
# Out:
# Index(['id', 'artist_name', 'track_name', 'popularity', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_in_ms',
#        'time_signature'],
#       dtype='object')

# %%
test_set[test_set.columns[test_set.isnull().any()]].isnull().sum()
# Out:
# popularity           95
# key                 405
# instrumentalness    836
# dtype: int64

# %%
test_set.hist(bins=50,figsize=(20,13))
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'danceability'}>,
#         <Axes: title={'center': 'energy'}>],
#        [<Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'mode'}>,
#         <Axes: title={'center': 'speechiness'}>],
#        [<Axes: title={'center': 'acousticness'}>,
#         <Axes: title={'center': 'instrumentalness'}>,
#         <Axes: title={'center': 'liveness'}>,
#         <Axes: title={'center': 'valence'}>],
#        [<Axes: title={'center': 'tempo'}>,
#         <Axes: title={'center': 'duration_in_ms'}>,
#         <Axes: title={'center': 'time_signature'}>, <Axes: >]],
#       dtype=object)

# %%
test_set.columns= test_set.columns.str.replace(" ","_").str.lower()
# columns = ["artist_name","track_name"]
# le = LabelEncoder()
# for col in columns:
#     test_set[col] = le.fit_transform(test_set[col])

transformed_columns_test_set = transformer.transform(test_set)
transformed_columns_test_set
# Out:
# test_set shape is (3600, 17)
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File e:\Python39\lib\site-packages\joblib\parallel.py:862, in Parallel.dispatch_one_batch(self, iterator)
#     861 try:
# --> 862     tasks = self._ready_batches.get(block=False)
#     863 except queue.Empty:
#     864     # slice the iterator n_jobs * batchsize items at a time. If the
#     865     # slice returns less than that, then the current batchsize puts
#    (...)
#     868     # accordingly to distribute evenly the last items between all
#     869     # workers.
#
# File e:\Python39\lib\queue.py:168, in Queue.get(self, block, timeout)
#     167     if not self._qsize():
# --> 168         raise Empty
#     169 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# l:\Python-data-ex\SHAI\shai-music-genre-classification-submission.ipynb Cell 82 in 1
#      <a href='vscode-notebook-cell:/l%3A/Python-data-ex/SHAI/shai-music-genre-classification-submission.ipynb#Y144sZmlsZQ%3D%3D?line=10'>11</a> test_set.columns= test_set.columns.str.replace(" ","_").str.lower()
#      <a href='vscode-notebook-cell:/l%3A/Python-data-ex/SHAI/shai-music-genre-classification-submission.ipynb#Y144sZmlsZQ%3D%3D?line=11'>12</a> # columns = ["artist_name","track_name"]
#      <a href='vscode-notebook-cell:/l%3A/Python-data-ex/SHAI/shai-music-genre-classification-submission.ipynb#Y144sZmlsZQ%3D%3D?line=12'>13</a> # le = LabelEncoder()
#      <a href='vscode-notebook-cell:/l%3A/Python-data-ex/SHAI/shai-music-genre-classification-submission.ipynb#Y144sZmlsZQ%3D%3D?line=13'>14</a> # for col in columns:
#      <a href='vscode-notebook-cell:/l%3A/Python-data-ex/SHAI/shai-music-genre-classification-submission.ipynb#Y144sZmlsZQ%3D%3D?line=14'>15</a> #     test_set[col] = le.fit_transform(test_set[col])
# ---> <a href='vscode-notebook-cell:/l%3A/Python-data-ex/SHAI/shai-music-genre-classification-submission.ipynb#Y144sZmlsZQ%3D%3D?line=16'>17</a> transformed_columns_test_set = transformer.transform(test_set)
#      <a href='vscode-notebook-cell:/l%3A/Python-data-ex/SHAI/shai-music-genre-classification-submission.ipynb#Y144sZmlsZQ%3D%3D?line=17'>18</a> transformed_columns_test_set
#
# File e:\Python39\lib\site-packages\sklearn\compose\_column_transformer.py:763, in ColumnTransformer.transform(self, X)
#     758 else:
#     759     # ndarray was used for fitting or transforming, thus we only
#     760     # check that n_features_in_ is consistent
#     761     self._check_n_features(X, reset=False)
# --> 763 Xs = self._fit_transform(
#     764     X,
#     765     None,
#     766     _transform_one,
#     767     fitted=True,
#     768     column_as_strings=fit_dataframe_and_transform_dataframe,
#     769 )
#     770 self._validate_output(Xs)
#     772 if not Xs:
#     773     # All transformers are None
#
# File e:\Python39\lib\site-packages\sklearn\compose\_column_transformer.py:621, in ColumnTransformer._fit_transform(self, X, y, func, fitted, column_as_strings)
#     615 transformers = list(
#     616     self._iter(
#     617         fitted=fitted, replace_strings=True, column_as_strings=column_as_strings
#     618     )
#     619 )
#     620 try:
# --> 621     return Parallel(n_jobs=self.n_jobs)(
#     622         delayed(func)(
#     623             transformer=clone(trans) if not fitted else trans,
#     624             X=_safe_indexing(X, column, axis=1),
#     625             y=y,
#     626             weight=weight,
#     627             message_clsname="ColumnTransformer",
#     628             message=self._log_message(name, idx, len(transformers)),
#     629         )
#     630         for idx, (name, trans, column, weight) in enumerate(transformers, 1)
#     631     )
#     632 except ValueError as e:
#     633     if "Expected 2D array, got 1D array instead" in str(e):
#
# File e:\Python39\lib\site-packages\joblib\parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File e:\Python39\lib\site-packages\joblib\parallel.py:873, in Parallel.dispatch_one_batch(self, iterator)
#     870 n_jobs = self._cached_effective_n_jobs
#     871 big_batch_size = batch_size * n_jobs
# --> 873 islice = list(itertools.islice(iterator, big_batch_size))
#     874 if len(islice) == 0:
#     875     return False
#
# File e:\Python39\lib\site-packages\sklearn\compose\_column_transformer.py:624, in <genexpr>(.0)
#     615 transformers = list(
#     616     self._iter(
#     617         fitted=fitted, replace_strings=True, column_as_strings=column_as_strings
#     618     )
#     619 )
#     620 try:
#     621     return Parallel(n_jobs=self.n_jobs)(
#     622         delayed(func)(
#     623             transformer=clone(trans) if not fitted else trans,
# --> 624             X=_safe_indexing(X, column, axis=1),
#     625             y=y,
#     626             weight=weight,
#     627             message_clsname="ColumnTransformer",
#     628             message=self._log_message(name, idx, len(transformers)),
#     629         )
#     630         for idx, (name, trans, column, weight) in enumerate(transformers, 1)
#     631     )
#     632 except ValueError as e:
#     633     if "Expected 2D array, got 1D array instead" in str(e):
#
# File e:\Python39\lib\site-packages\sklearn\utils\__init__.py:359, in _safe_indexing(X, indices, axis)
#     353     raise ValueError(
#     354         "Specifying the columns using strings is only supported for "
#     355         "pandas DataFrames"
#     356     )
#     358 if hasattr(X, "iloc"):
# --> 359     return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     360 elif hasattr(X, "shape"):
#     361     return _array_indexing(X, indices, indices_dtype, axis=axis)
#
# File e:\Python39\lib\site-packages\sklearn\utils\__init__.py:205, in _pandas_indexing(X, key, key_dtype, axis)
#     202 else:
#     203     # check whether we should index with loc or iloc
#     204     indexer = X.iloc if key_dtype == "int" else X.loc
# --> 205     return indexer[:, key] if axis else indexer[key]
#
# File e:\Python39\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File e:\Python39\lib\site-packages\pandas\core\indexing.py:1149, in _LocIndexer._getitem_tuple(self, tup)
#    1146 if self._multi_take_opportunity(tup):
#    1147     return self._multi_take(tup)
# -> 1149 return self._getitem_tuple_same_dim(tup)
#
# File e:\Python39\lib\site-packages\pandas\core\indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     824 if com.is_null_slice(key):
#     825     continue
# --> 827 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828 # We should never have retval.ndim < self.ndim, as that should
#     829 #  be handled by the _getitem_lowerdim call above.
#     830 assert retval.ndim == self.ndim
#
# File e:\Python39\lib\site-packages\pandas\core\indexing.py:1194, in _LocIndexer._getitem_axis(self, key, axis)
#    1191     if hasattr(key, "ndim") and key.ndim > 1:
#    1192         raise ValueError("Cannot index with multidimensional key")
# -> 1194     return self._getitem_iterable(key, axis=axis)
#    1196 # nested tuple slicing
#    1197 if is_nested_tuple(key, labels):
#
# File e:\Python39\lib\site-packages\pandas\core\indexing.py:1132, in _LocIndexer._getitem_iterable(self, key, axis)
#    1129 self._validate_key(key, axis)
#    1131 # A collection of keys
# -> 1132 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133 return self.obj._reindex_with_indexers(
#    1134     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1135 )
#
# File e:\Python39\lib\site-packages\pandas\core\indexing.py:1330, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1327 ax = self.obj._get_axis(axis)
#    1328 axis_name = self.obj._get_axis_name(axis)
# -> 1330 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1332 return keyarr, indexer
#
# File e:\Python39\lib\site-packages\pandas\core\indexes\base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File e:\Python39\lib\site-packages\pandas\core\indexes\base.py:5859, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['duration_in_ms'] not in index"

# %% [markdown]
# Appllying the model with the highest accuracy to Test dataset

# %%
stack_clf
stack_clf.fit(transformed_columns,y_train)

pred =stack_clf.predict(transformed_columns_test_set)
# Out:
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# e:\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Using RandomForestClassifier becasue it returned better results
# rfc.fit(transformed_columns,y_train)

# test_drop = test_set.drop(['Id','Artist Name','Track Name'],axis=1)

# pred =rfc.predict(transformer.transform(test_drop))
# pred.shape

# %%
data = {'Id': Id, 'Class':pred}
sub = pd.DataFrame(data=data)
print(sub)
# Out:
#          Id  Class
# 0     14397      9
# 1     14398      6
# 2     14399      9
# 3     14400     10
# 4     14401      5
# ...     ...    ...
# 3595  17992     10
# 3596  17993      5
# 3597  17994      6
# 3598  17995      2
# 3599  17996     10
#
# [3600 rows x 2 columns]

# %% [markdown]
# Saving the prediction

# %%
sub.to_csv('shai-music-genre-classification-rfc-xgb-log-labeleno-stacking.csv',index=False)

# %% [markdown]
# # Other possible modifications

# %% [markdown]
# 1- Using RandomForestClassifier Feature importance

# %%
from sklearn.ensemble import RandomForestClassifier
rnd_clf = RandomForestClassifier(n_estimators=500,random_state=42)
rnd_clf.fit(transformed_columns, y_train)
for score, name in zip(rnd_clf.feature_importances_, train_set.columns):
    print(round(score, 2), name)
# Out:
# 0.08 Artist Name
# 0.09 Track Name
# 0.09 Popularity
# 0.04 danceability
# 0.08 energy
# 0.01 key
# 0.1 loudness
# 0.1 mode
# 0.08 speechiness
# 0.06 acousticness
# 0.08 instrumentalness
# 0.06 liveness
# 0.12 valence
# 0.01 tempo
